# %% [markdown]
# ## This is notebook contains the implementation of the methodologies listed in the paper. The notebook is divided into the following parts:-
#
# - Part 1: Data Gathering and cleaning
# - Part 2: Exploratory Data Analysis
# - Part 3: Bias Evaluation
# - Part 4: Reference

# %% [markdown]
# #### We will require following libraries for implementing all the sections mentioned in the notebook

# %%
import csv
import PyPDF2
import numpy as np
import nltk
from nltk import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wefe.query import Query
from wefe.word_embedding_model import WordEmbeddingModel
import gensim.downloader as api
from sklearn.decomposition import PCA
import glob, os
import pandas as pd
from wefe.metrics.WEAT import WEAT
from wefe.metrics import RND
from gensim.models import KeyedVectors
from gensim.models import Word2Vec, FastText
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Data Location
#
# This is to set the location from where we want to retrieve the data and where do we want to store the data files which will be created while executing the code

# %%
input_data_location = '/home/bhawna/text_analytics/Gender_Dimension/data'
output_data_location = '/home/bhawna/text_analytics/Gender_Dimension/output_new'
fairness_output_location = '/home/bhawna/text_analytics/Gender_Dimension/output_fairness'
output_bigrams = '/home/bhawna/text_analytics/Gender_Dimension/bigram'
vector_location = '/home/bhawna/text_analytics/Gender_Dimension/GoogleNews-vectors-negative300.bin.gz'

# %% [markdown]
# ## Part 1: Data Gathering and Cleaning

# %% [markdown]
# The goal of this section is to take NECPs (pdf format) from our data folder and create a CSV file for each country in the EU region with the occurance of the top 100 words in the pdf file.

# %% [markdown]
# #### Gathering input files from the data

# %%
os.chdir(input_data_location)
all_necps_filepath = []
for file in glob.glob("*main_en_0.pdf"):
    all_necps_filepath.append(file)

# %% [markdown]
# #### Getting the total no. of files in the data folder

# %%
len(all_necps_filepath)
# Out:
# 27

# %% [markdown]
# Checking the names of the files to confirm if we have retrived the right set of files

# %%
all_necps_filepath
# Out:
# ['bg_final_necp_main_en_0.pdf',
#  'pl_final_necp_main_en_0.pdf',
#  'ro_final_necp_main_en_0.pdf',
#  'nl_final_necp_main_en_0.pdf',
#  'hu_final_necp_main_en_0.pdf',
#  'it_final_necp_main_en_0.pdf',
#  'el_final_necp_main_en_0.pdf',
#  'dk_final_necp_main_en_0.pdf',
#  'ee_final_necp_main_en_0.pdf',
#  'si_final_necp_main_en_0.pdf',
#  'at_final_necp_main_en_0.pdf',
#  'fi_final_necp_main_en_0.pdf',
#  'fr_final_necp_main_en_0.pdf',
#  'ie_final_necp_main_en_0.pdf',
#  'cy_final_necp_main_en_0.pdf',
#  'de_final_necp_main_en_0.pdf',
#  'es_final_necp_main_en_0.pdf',
#  'sk_final_necp_main_en_0.pdf',
#  'be_final_necp_main_en_0.pdf',
#  'se_final_necp_main_en_0.pdf',
#  'pt_final_necp_main_en_0.pdf',
#  'mt_final_necp_main_en_0.pdf',
#  'lu_final_necp_main_en_0.pdf',
#  'lv_final_necp_main_en_0.pdf',
#  'hr_final_necp_main_en_0.pdf',
#  'lt_final_necp_main_en_0.pdf',
#  'cs_final_necp_main_en_0.pdf']

# %% [markdown]
# #### Getting the names of the file

# %% [markdown]
# We need to create a list of the name of the file before the .pdf extension to execute the following piece of code

# %%
necps_names = [os.path.splitext(i)[0] for i in all_necps_filepath]

# %%
necps_names
# Out:
# ['bg_final_necp_main_en_0',
#  'pl_final_necp_main_en_0',
#  'ro_final_necp_main_en_0',
#  'nl_final_necp_main_en_0',
#  'hu_final_necp_main_en_0',
#  'it_final_necp_main_en_0',
#  'el_final_necp_main_en_0',
#  'dk_final_necp_main_en_0',
#  'ee_final_necp_main_en_0',
#  'si_final_necp_main_en_0',
#  'at_final_necp_main_en_0',
#  'fi_final_necp_main_en_0',
#  'fr_final_necp_main_en_0',
#  'ie_final_necp_main_en_0',
#  'cy_final_necp_main_en_0',
#  'de_final_necp_main_en_0',
#  'es_final_necp_main_en_0',
#  'sk_final_necp_main_en_0',
#  'be_final_necp_main_en_0',
#  'se_final_necp_main_en_0',
#  'pt_final_necp_main_en_0',
#  'mt_final_necp_main_en_0',
#  'lu_final_necp_main_en_0',
#  'lv_final_necp_main_en_0',
#  'hr_final_necp_main_en_0',
#  'lt_final_necp_main_en_0',
#  'cs_final_necp_main_en_0']

# %% [markdown]
# After getting the list, we will define another list to generate a dataframe for a creating a summary of the files anlzyed.
# In the dataframe we would like to see the name of the file, the no of pages present in the file, total no of the words in the file and the no. of words being extracted from the file and finally the ratio of the top_count and the count_total_words to indicate the document coverage by the top_count.

# %%
info_being_gathered = [['Document', 'Page_Count', 'Count_Total_Words', 'Top_Count', 'Ratio']]

# %% [markdown]
# We next define a function which performs Pre-processing and returns us a CSV file containg top 100 words for all the pdfs files

# %% [markdown]
# '''
# The function below is used to calculate the top 100 words for each NECP.
# The function takes four parameters:-
#  - top_count : This parameter decides the no. of of words to be extracted, for now it is 100
#  - all_necps_filepath  : This is the list containing paths of all files
#  - necps_name: This list contains names of all the files
#  - info_being_gathered: This is an empty list in which we will collect reflect how much fraction of data is being represented by top 100 words
# '''

# %%
def top_words(top_count, all_necps_filepath, necps_name, info_being_gathered):
    
    list_of_100words = []

    for necp, necp_name in zip(all_necps_filepath,necps_name):
        
        count_word = top_count
        # read the pdf file.
        pdfFileObj = open(necp, 'rb')

        # Parse the pdf file reader object .
        pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

        # iterate and parse through all the pages in the pdf file.
        num_pages = pdfReader.numPages
        count = 0
        text = ""

        while count < num_pages:
            pageObj = pdfReader.getPage(count)
            count += 1
            text += pageObj.extractText()
            
        page_count = count
        print("The no of pages in the document is ", count)
        # word_tokenize to break a sentence into constituent words
        tokens = word_tokenize(text)

        # eliminate the punctuation marks
        tokens = [word for word in tokens if len(word) > 1]
        punctuations = ['(', ')', ';', ':', '[', ']', ',', '.']

        # we use NLTK's pre-defined stopwords and the four additional stop words that occur a lot in the data 

        stop_words = stopwords.words('english')
        also_stop_words = ['also', 'total', 'use', 'new']
        
        total_stop_words = stop_words + also_stop_words

        # list comprehension to return a list of words that are neither stop_words nor punctuations.
        keywords = [word for word in tokens if not word.lower() in total_stop_words and not word in punctuations]
        keywords = [i for i in keywords if i.isalpha()]

        # create a frequency distribution 
        f_dist = FreqDist()
        for word in keywords:
            f_dist[word.lower()] += 1
        
        # taking the bigrams     
        bgs = nltk.bigrams(keywords)

        # compute frequency distribution for all the bigrams in the text
        fdist2 = nltk.FreqDist(bgs)
        
        # defining the path file to store the top 100 words
        list_of_100words.append(f_dist.most_common(count_word))
        necp_final_name = necp_name + ".csv"
        final_path = os.path.join(output_data_location, necp_final_name)
        final_path_bigrm = os.path.join(output_bigrams, necp_final_name)
        
        total_sum = sum(f_dist.values())
        #print(f_dist.most_common(count_word))
        top_count_sum= sum(j for i, j in f_dist.most_common(count_word))
        percentage = (top_count_sum/total_sum)*100
        name = necp_name
        
        # populate the summary table 
        info_per_necp = [name, page_count, total_sum, top_count_sum, percentage]
        info_being_gathered.append(info_per_necp)
        
        # create and write a csv for storing the unigrams in the file
        with open(final_path, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["word", "weight"])
            writer.writerows(f_dist.most_common(count_word))
            
        # create and write a csv for storing the bigrams in the file
        with open(final_path_bigrm, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["word", "weight"])
            writer.writerows(fdist2.most_common(count_word))
        

        print(list_of_100words)  
        print("*************************")
        print("For document ", necp_name)
        # print all of data
        print(f_dist.most_common(count_word))
        
    return info_being_gathered, list_of_100words

# %%
information_100, list_of_100words = top_words(100, all_necps_filepath,necps_names, info_being_gathered)
# Out:
# The no of pages in the document is  280
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)]]
# *************************
# For document  bg_final_necp_main_en_0
# [('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)]
# The no of pages in the document is  401
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)], [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)]]
# *************************
# For document  pl_final_necp_main_en_0
# [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)]
# The no of pages in the document is  228
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)], [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)], [('energy', 1721), ('national', 543), ('electricity', 459), ('plan', 379), ('measures', 372), ('romania', 359), ('gas', 331), ('climate', 327), ('development', 315), ('consumption', 299), ('sector', 298), ('renewable', 291), ('market', 289), ('eu', 282), ('emissions', 256), ('final', 255), ('efficiency', 251), ('system', 247), ('natural', 239), ('res', 230), ('tegrated', 225), ('transmission', 225), ('transport',  ...
# *************************
# For document  ro_final_necp_main_en_0
# [('energy', 1721), ('national', 543), ('electricity', 459), ('plan', 379), ('measures', 372), ('romania', 359), ('gas', 331), ('climate', 327), ('development', 315), ('consumption', 299), ('sector', 298), ('renewable', 291), ('market', 289), ('eu', 282), ('emissions', 256), ('final', 255), ('efficiency', 251), ('system', 247), ('natural', 239), ('res', 230), ('tegrated', 225), ('transmission', 225), ('transport', 223), ('order', 220), ('policies', 213), ('production', 207), ('capacity', 196), ('increase', 191), ('european', 183), ('research', 179), ('projects', 172), ('level', 169), ('sources', 162), ('ghg', 157), ('including', 151), ('source', 150), ('period', 143), ('implementation', 142), ('capacities', 141), ('de', 137), ('main', 132), ('consumers', 132), ('trend', 129), ('following', 128), ('commission', 125), ('public', 122), ('inecp', 121), ('current', 120), ('share', 116), ('chart', 114), ('reduction', 114), ('support', 114), ('based', 113), ('dimension', 110), ('security', 110), ('kv', 110), ('objectives', 105), ('supply', 105), ('storage', 105), ('targets', 103), ('scenario', 103), ('decarbonisation', 102), ('infrastructure', 102), ('table', 99), ('target', 99), ('industrial', 98), ('innovation', 97), ('projected', 97), ('smart', 96), ('million', 95), ('eur', 94), ('technologies', 93), ('power', 92), ('investments', 92), ('regulation', 92), ('systems', 91), ('ministry', 91), ('moreover', 91), ('price', 89), ('heating', 87), ('context', 86), ('demand', 86), ('heat', 84), ('buildings', 83), ('strategy', 82), ('environment', 82), ('project', 82), ('member', 81), ('accordance', 81), ('impact', 79), ('ro', 79), ('existing', 77), ('costs', 77), ('developing', 77), ('directive', 77), ('regarding', 76), ('carbon', 76), ('compared', 76), ('transition', 75), ('investment', 75)]
# The no of pages in the document is  170
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)], [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)], [('energy', 1721), ('national', 543), ('electricity', 459), ('plan', 379), ('measures', 372), ('romania', 359), ('gas', 331), ('climate', 327), ('development', 315), ('consumption', 299), ('sector', 298), ('renewable', 291), ('market', 289), ('eu', 282), ('emissions', 256), ('final', 255), ('efficiency', 251), ('system', 247), ('natural', 239), ('res', 230), ('tegrated', 225), ('transmission', 225), ('transport',  ...
# *************************
# For document  nl_final_necp_main_en_0
# [('energy', 1594), ('climate', 657), ('gas', 504), ('netherlands', 461), ('national', 349), ('electricity', 345), ('co', 327), ('emissions', 320), ('renewable', 319), ('policy', 305), ('agreement', 291), ('measures', 263), ('market', 232), ('consumption', 228), ('plan', 224), ('expected', 216), ('policies', 200), ('reduction', 179), ('environment', 178), ('supply', 172), ('savings', 171), ('government', 170), ('innovation', 168), ('increase', 167), ('integrated', 166), ('european', 158), ('sector', 154), ('investments', 151), ('built', 150), ('greenhouse', 146), ('pbl', 142), ('including', 139), ('due', 138), ('industry', 135), ('heat', 135), ('sustainable', 133), ('target', 131), ('based', 131), ('natural', 131), ('system', 130), ('dutch', 126), ('years', 123), ('price', 122), ('wind', 121), ('demand', 120), ('related', 119), ('see', 119), ('transition', 114), ('generation', 114), ('development', 114), ('result', 111), ('countries', 110), ('per', 110), ('period', 109), ('tax', 107), ('costs', 106), ('sectors', 106), ('transport', 104), ('regional', 102), ('capacity', 101), ('level', 101), ('high', 101), ('figure', 101), ('power', 98), ('kev', 97), ('megatons', 97), ('addition', 96), ('share', 96), ('decrease', 96), ('sources', 95), ('low', 95), ('production', 94), ('equivalents', 91), ('growth', 91), ('year', 88), ('economic', 87), ('approach', 87), ('petajoules', 87), ('emission', 86), ('research', 84), ('number', 84), ('targets', 83), ('achieve', 83), ('eu', 83), ('important', 83), ('adopted', 81), ('term', 81), ('mobility', 81), ('buildings', 80), ('households', 80), ('effects', 79), ('available', 79), ('euros', 79), ('document', 78), ('cost', 78), ('prices', 78), ('small', 78), ('used', 77), ('consumers', 77), ('security', 76)]
# The no of pages in the document is  305
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)], [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)], [('energy', 1721), ('national', 543), ('electricity', 459), ('plan', 379), ('measures', 372), ('romania', 359), ('gas', 331), ('climate', 327), ('development', 315), ('consumption', 299), ('sector', 298), ('renewable', 291), ('market', 289), ('eu', 282), ('emissions', 256), ('final', 255), ('efficiency', 251), ('system', 247), ('natural', 239), ('res', 230), ('tegrated', 225), ('transmission', 225), ('transport',  ...
# *************************
# For document  hu_final_necp_main_en_0
# [('energy', 1563), ('gas', 576), ('consumption', 555), ('electricity', 516), ('hungary', 402), ('market', 395), ('hungarian', 385), ('renewable', 361), ('natural', 296), ('system', 270), ('transport', 254), ('based', 249), ('figure', 247), ('measures', 238), ('power', 232), ('national', 231), ('sector', 230), ('share', 225), ('increase', 215), ('european', 213), ('production', 210), ('data', 204), ('supply', 197), ('sources', 186), ('capacity', 182), ('emissions', 178), ('development', 175), ('eu', 173), ('capacities', 173), ('efficiency', 169), ('within', 163), ('final', 162), ('source', 158), ('network', 151), ('security', 134), ('demand', 129), ('storage', 129), ('climate', 127), ('necessary', 127), ('heating', 125), ('projects', 124), ('level', 123), ('relation', 121), ('regulation', 121), ('scenario', 120), ('wam', 119), ('expected', 118), ('wem', 118), ('may', 118), ('https', 115), ('cost', 113), ('hu', 113), ('generation', 112), ('point', 111), ('price', 110), ('nuclear', 110), ('ktoe', 109), ('plan', 108), ('plant', 108), ('heat', 108), ('table', 106), ('year', 105), ('change', 103), ('innovation', 101), ('prices', 99), ('period', 99), ('chapter', 97), ('costs', 95), ('transmission', 94), ('policy', 94), ('en', 94), ('support', 94), ('industrial', 93), ('ghg', 91), ('policies', 90), ('including', 90), ('number', 90), ('sectors', 89), ('import', 89), ('technologies', 89), ('retail', 88), ('relating', 88), ('implementation', 88), ('significantly', 88), ('co', 87), ('high', 87), ('markets', 85), ('billion', 84), ('directive', 84), ('buildings', 83), ('research', 82), ('million', 82), ('eurostat', 82), ('distribution', 81), ('services', 81), ('border', 79), ('oil', 78), ('industry', 78), ('plants', 78), ('additional', 78)]
# The no of pages in the document is  329
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)], [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)], [('energy', 1721), ('national', 543), ('electricity', 459), ('plan', 379), ('measures', 372), ('romania', 359), ('gas', 331), ('climate', 327), ('development', 315), ('consumption', 299), ('sector', 298), ('renewable', 291), ('market', 289), ('eu', 282), ('emissions', 256), ('final', 255), ('efficiency', 251), ('system', 247), ('natural', 239), ('res', 230), ('tegrated', 225), ('transmission', 225), ('transport',  ...
# *************************
# For document  it_final_necp_main_en_0
# [('energy', 1764), ('national', 709), ('plan', 562), ('measures', 496), ('sector', 478), ('electricity', 469), ('climate', 429), ('december', 408), ('gas', 384), ('development', 382), ('integrated', 379), ('consumption', 357), ('italy', 346), ('transport', 334), ('renewable', 334), ('efficiency', 322), ('system', 317), ('market', 290), ('production', 269), ('including', 260), ('network', 247), ('public', 244), ('decree', 238), ('emissions', 230), ('economic', 229), ('plants', 228), ('sources', 216), ('systems', 214), ('res', 209), ('increase', 204), ('law', 201), ('million', 197), ('policies', 190), ('power', 178), ('order', 175), ('eu', 172), ('european', 170), ('buildings', 167), ('research', 165), ('scenario', 163), ('storage', 162), ('infrastructure', 160), ('year', 159), ('environmental', 157), ('sectors', 155), ('reduction', 154), ('italian', 154), ('objectives', 153), ('set', 153), ('resources', 152), ('services', 148), ('used', 148), ('renewables', 147), ('target', 146), ('existing', 145), ('following', 145), ('table', 144), ('non', 142), ('article', 142), ('terms', 140), ('supply', 139), ('capacity', 138), ('heating', 138), ('targets', 136), ('areas', 134), ('particular', 133), ('demand', 131), ('projects', 131), ('support', 129), ('potential', 127), ('ministry', 126), ('vehicles', 126), ('current', 125), ('final', 125), ('generation', 124), ('level', 123), ('source', 122), ('period', 120), ('inecp', 118), ('made', 118), ('years', 114), ('end', 114), ('around', 114), ('basis', 113), ('waste', 113), ('security', 112), ('impact', 111), ('natural', 109), ('technologies', 109), ('local', 109), ('expected', 109), ('regulation', 108), ('electric', 108), ('heat', 105), ('part', 104), ('possible', 102), ('fuels', 102), ('figure', 101), ('share', 100), ('directive', 99)]
# The no of pages in the document is  335
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)], [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)], [('energy', 1721), ('national', 543), ('electricity', 459), ('plan', 379), ('measures', 372), ('romania', 359), ('gas', 331), ('climate', 327), ('development', 315), ('consumption', 299), ('sector', 298), ('renewable', 291), ('market', 289), ('eu', 282), ('emissions', 256), ('final', 255), ('efficiency', 251), ('system', 247), ('natural', 239), ('res', 230), ('tegrated', 225), ('transmission', 225), ('transport',  ...
# *************************
# For document  el_final_necp_main_en_0
# [('energy', 1871), ('res', 661), ('measures', 504), ('electricity', 501), ('consumption', 463), ('development', 398), ('policy', 385), ('sector', 383), ('final', 329), ('gas', 317), ('generation', 311), ('efficiency', 282), ('objective', 281), ('power', 268), ('transport', 268), ('market', 264), ('measure', 258), ('national', 246), ('objectives', 240), ('system', 237), ('systems', 228), ('emissions', 218), ('climate', 216), ('period', 210), ('implementation', 208), ('greece', 206), ('plants', 204), ('increase', 197), ('share', 194), ('regulatory', 189), ('chart', 181), ('necp', 179), ('economic', 178), ('framework', 178), ('policies', 169), ('natural', 168), ('projects', 166), ('storage', 164), ('specific', 160), ('context', 156), ('sectors', 156), ('buildings', 153), ('promoting', 152), ('domestic', 152), ('management', 151), ('technologies', 147), ('well', 144), ('actions', 143), ('eu', 143), ('public', 140), ('reduction', 138), ('article', 135), ('table', 135), ('expected', 134), ('economy', 133), ('vehicles', 131), ('change', 128), ('compared', 127), ('improvement', 127), ('heating', 125), ('plan', 123), ('areas', 120), ('support', 120), ('penetration', 118), ('necessary', 115), ('priorities', 114), ('key', 109), ('account', 109), ('supply', 109), ('financing', 108), ('greek', 105), ('planning', 105), ('following', 104), ('cost', 103), ('operation', 103), ('capacity', 103), ('sustainable', 102), ('lignite', 102), ('technical', 101), ('interconnection', 100), ('evolution', 100), ('level', 99), ('particular', 98), ('waste', 98), ('relevant', 98), ('high', 98), ('financial', 98), ('transition', 96), ('contribution', 94), ('reducing', 93), ('year', 93), ('infrastructure', 92), ('existing', 92), ('order', 88), ('cooling', 87), ('products', 87), ('significant', 87), ('ghg', 86), ('fuel', 85), ('programmes', 84)]
# The no of pages in the document is  184
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)], [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)], [('energy', 1721), ('national', 543), ('electricity', 459), ('plan', 379), ('measures', 372), ('romania', 359), ('gas', 331), ('climate', 327), ('development', 315), ('consumption', 299), ('sector', 298), ('renewable', 291), ('market', 289), ('eu', 282), ('emissions', 256), ('final', 255), ('efficiency', 251), ('system', 247), ('natural', 239), ('res', 230), ('tegrated', 225), ('transmission', 225), ('transport',  ...
# *************************
# For document  dk_final_necp_main_en_0
# [('energy', 1181), ('denmark', 470), ('danish', 334), ('electricity', 331), ('gas', 304), ('climate', 241), ('measures', 205), ('sector', 190), ('renewable', 189), ('emissions', 186), ('agreement', 186), ('nordic', 178), ('market', 177), ('consumption', 170), ('wind', 169), ('heating', 162), ('national', 156), ('production', 146), ('system', 143), ('heat', 140), ('green', 137), ('projects', 137), ('support', 136), ('government', 129), ('expected', 127), ('plan', 126), ('eu', 124), ('supply', 122), ('development', 120), ('share', 120), ('policies', 116), ('efficiency', 113), ('including', 113), ('figure', 106), ('biomass', 106), ('based', 105), ('increase', 104), ('dkk', 103), ('research', 101), ('power', 101), ('transport', 100), ('countries', 98), ('security', 96), ('target', 94), ('level', 94), ('offshore', 94), ('cooperation', 93), ('well', 92), ('district', 87), ('point', 87), ('information', 85), ('price', 82), ('regulation', 81), ('capacity', 80), ('public', 80), ('buildings', 76), ('technology', 76), ('policy', 75), ('targets', 73), ('scheme', 73), ('grid', 73), ('greenhouse', 72), ('single', 71), ('transition', 69), ('natural', 69), ('section', 68), ('technologies', 68), ('shows', 68), ('project', 68), ('part', 67), ('objectives', 67), ('action', 65), ('set', 65), ('existing', 64), ('sectors', 64), ('tax', 64), ('sources', 62), ('year', 61), ('large', 61), ('land', 61), ('related', 60), ('parties', 60), ('initiatives', 60), ('future', 60), ('demand', 60), ('period', 59), ('years', 59), ('ets', 58), ('act', 58), ('final', 58), ('north', 57), ('towards', 56), ('oil', 56), ('council', 54), ('used', 54), ('order', 54), ('lulucf', 54), ('data', 54), ('june', 53), ('see', 53)]
# The no of pages in the document is  195
# ...
# *************************
# For document  hr_final_necp_main_en_0
# [('energy', 1658), ('measures', 509), ('system', 475), ('gas', 473), ('development', 446), ('croatia', 362), ('efficiency', 360), ('measure', 347), ('implementation', 329), ('electricity', 327), ('emissions', 297), ('national', 286), ('republic', 280), ('climate', 273), ('consumption', 253), ('transmission', 239), ('period', 234), ('res', 230), ('market', 226), ('plan', 224), ('public', 224), ('funds', 223), ('production', 220), ('buildings', 208), ('activities', 207), ('change', 203), ('systems', 203), ('sources', 200), ('existing', 196), ('eu', 196), ('research', 195), ('transport', 191), ('sector', 189), ('co', 177), ('power', 177), ('monitoring', 176), ('supply', 169), ('greenhouse', 168), ('og', 167), ('figure', 160), ('management', 154), ('act', 142), ('emission', 140), ('renovation', 140), ('expected', 138), ('grid', 138), ('construction', 135), ('reduction', 135), ('within', 132), ('infrastructure', 132), ('year', 129), ('level', 128), ('building', 127), ('technologies', 127), ('programme', 127), ('renewable', 126), ('projects', 126), ('carbon', 125), ('protection', 124), ('increasing', 123), ('table', 122), ('information', 118), ('increase', 118), ('amount', 116), ('adaptation', 115), ('connection', 115), ('reducing', 108), ('capacity', 107), ('plants', 106), ('related', 106), ('strategy', 104), ('security', 103), ('storage', 102), ('necessary', 102), ('ministry', 101), ('regional', 101), ('body', 98), ('savings', 97), ('croatian', 96), ('scenario', 96), ('according', 92), ('investment', 92), ('end', 91), ('products', 91), ('framework', 89), ('dimension', 88), ('waste', 88), ('objective', 88), ('regulatory', 87), ('european', 86), ('natural', 86), ('financial', 86), ('hrk', 86), ('well', 85), ('non', 85), ('share', 85), ('low', 85), ('estimated', 85), ('mee', 85), ('policies', 84)]
# The no of pages in the document is  273
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)], [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)], [('energy', 1721), ('national', 543), ('electricity', 459), ('plan', 379), ('measures', 372), ('romania', 359), ('gas', 331), ('climate', 327), ('development', 315), ('consumption', 299), ('sector', 298), ('renewable', 291), ('market', 289), ('eu', 282), ('emissions', 256), ('final', 255), ('efficiency', 251), ('system', 247), ('natural', 239), ('res', 230), ('tegrated', 225), ('transmission', 225), ('transport',  ...
# *************************
# For document  lt_final_necp_main_en_0
# [('energy', 1461), ('measures', 779), ('electricity', 614), ('gas', 510), ('sector', 480), ('lithuania', 465), ('res', 403), ('ministry', 403), ('ghg', 402), ('transport', 395), ('emissions', 353), ('national', 318), ('development', 311), ('policies', 304), ('section', 289), ('system', 284), ('eu', 281), ('natural', 277), ('waste', 272), ('climate', 269), ('change', 259), ('heat', 250), ('consumption', 249), ('production', 248), ('planned', 241), ('power', 240), ('market', 235), ('public', 233), ('plan', 226), ('lithuanian', 221), ('efficiency', 217), ('implementation', 216), ('fuel', 206), ('increase', 191), ('policy', 190), ('supply', 183), ('existing', 181), ('capacity', 181), ('technologies', 178), ('plants', 178), ('heating', 166), ('environment', 158), ('european', 154), ('co', 152), ('transmission', 152), ('share', 150), ('ktoe', 148), ('sources', 144), ('management', 144), ('renewable', 143), ('period', 142), ('sectors', 140), ('measure', 139), ('generation', 138), ('reduction', 136), ('targets', 135), ('ensure', 132), ('baltic', 128), ('reduce', 128), ('support', 127), ('order', 127), ('eur', 127), ('industrial', 125), ('consumers', 123), ('mw', 122), ('systems', 121), ('security', 121), ('impact', 119), ('would', 117), ('agriculture', 116), ('buildings', 115), ('states', 114), ('current', 113), ('vehicles', 113), ('year', 113), ('projections', 111), ('table', 111), ('promote', 109), ('infrastructure', 108), ('projected', 106), ('objectives', 106), ('innovation', 105), ('used', 104), ('projects', 103), ('per', 103), ('situation', 101), ('areas', 101), ('ets', 100), ('industry', 100), ('biofuel', 97), ('expected', 96), ('level', 96), ('final', 95), ('economy', 95), ('price', 95), ('programme', 94), ('fuels', 92), ('compared', 92), ('non', 92), ('networks', 91)]
# The no of pages in the document is  442
# [[('energy', 1886), ('electricity', 659), ('gas', 618), ('bulgaria', 524), ('renewable', 475), ('measures', 468), ('national', 446), ('sector', 432), ('emissions', 394), ('consumption', 373), ('sources', 346), ('eu', 322), ('market', 317), ('transport', 301), ('efficiency', 296), ('period', 286), ('development', 259), ('power', 252), ('natural', 245), ('transmission', 240), ('including', 238), ('capacity', 238), ('final', 231), ('generation', 229), ('increase', 228), ('plants', 227), ('biomass', 205), ('set', 202), ('heating', 201), ('buildings', 199), ('policy', 198), ('waste', 198), ('projected', 197), ('european', 197), ('share', 193), ('ktoe', 189), ('implementation', 188), ('fuels', 188), ('plan', 184), ('system', 179), ('co', 176), ('directive', 170), ('ghg', 168), ('project', 165), ('heat', 153), ('infrastructure', 150), ('source', 145), ('requirements', 145), ('scenario', 144), ('projects', 143), ('existing', 142), ('production', 137), ('expected', 132), ('compared', 131), ('account', 130), ('network', 130), ('climate', 128), ('supply', 127), ('year', 127), ('targets', 126), ('systems', 125), ('line', 125), ('regulation', 125), ('management', 120), ('target', 119), ('construction', 117), ('accordance', 116), ('area', 116), ('model', 116), ('public', 115), ('change', 115), ('sectors', 113), ('consumers', 112), ('ensure', 112), ('modelling', 112), ('reduction', 112), ('union', 111), ('following', 111), ('support', 108), ('programme', 108), ('security', 107), ('bulgarian', 106), ('air', 104), ('gwh', 104), ('storage', 101), ('distribution', 101), ('eq', 100), ('gross', 99), ('projections', 99), ('potential', 99), ('regional', 97), ('prices', 97), ('table', 96), ('level', 96), ('article', 95), ('building', 95), ('used', 95), ('est', 95), ('policies', 92), ('applicable', 92)], [('energy', 2811), ('gas', 825), ('electricity', 754), ('poland', 657), ('development', 641), ('measures', 625), ('transport', 556), ('sector', 550), ('power', 546), ('scenario', 509), ('ecp', 473), ('national', 447), ('production', 429), ('consumption', 425), ('system', 420), ('market', 418), ('table', 413), ('policies', 408), ('efficiency', 389), ('fuel', 386), ('capacity', 386), ('emissions', 384), ('heat', 377), ('renewable', 369), ('fuels', 368), ('share', 350), ('increase', 336), ('sources', 333), ('eu', 320), ('transmission', 317), ('including', 305), ('heating', 303), ('coal', 303), ('final', 300), ('generation', 298), ('plants', 295), ('natural', 293), ('polish', 292), ('ref', 274), ('prices', 273), ('res', 269), ('support', 260), ('necp', 257), ('impact', 254), ('sectors', 254), ('technologies', 249), ('demand', 246), ('figure', 240), ('source', 239), ('infrastructure', 231), ('european', 217), ('emission', 212), ('high', 211), ('units', 211), ('oil', 208), ('existing', 207), ('nuclear', 205), ('economy', 204), ('research', 203), ('construction', 203), ('co', 202), ('based', 201), ('level', 200), ('potential', 200), ('data', 198), ('current', 196), ('assessment', 196), ('low', 194), ('economic', 192), ('projects', 191), ('climate', 189), ('million', 185), ('projections', 185), ('network', 183), ('storage', 183), ('gross', 177), ('used', 173), ('annex', 172), ('well', 171), ('eur', 171), ('systems', 168), ('expected', 168), ('security', 167), ('period', 167), ('dimension', 167), ('costs', 167), ('industry', 165), ('waste', 163), ('implementation', 162), ('non', 162), ('areas', 161), ('supply', 161), ('buildings', 160), ('end', 159), ('changes', 155), ('approx', 155), ('year', 155), ('district', 154), ('policy', 153), ('plan', 149)], [('energy', 1721), ('national', 543), ('electricity', 459), ('plan', 379), ('measures', 372), ('romania', 359), ('gas', 331), ('climate', 327), ('development', 315), ('consumption', 299), ('sector', 298), ('renewable', 291), ('market', 289), ('eu', 282), ('emissions', 256), ('final', 255), ('efficiency', 251), ('system', 247), ('natural', 239), ('res', 230), ('tegrated', 225), ('transmission', 225), ('transport',  ...
# *************************
# For document  cs_final_necp_main_en_0
# [('energy', 2802), ('czech', 1018), ('republic', 849), ('gas', 806), ('savings', 757), ('measures', 724), ('electricity', 670), ('development', 662), ('system', 531), ('sources', 529), ('table', 527), ('national', 513), ('consumption', 510), ('support', 454), ('eu', 400), ('individual', 390), ('market', 389), ('sector', 387), ('plan', 383), ('policy', 364), ('source', 337), ('state', 324), ('transmission', 323), ('transport', 316), ('chart', 310), ('measure', 301), ('production', 295), ('information', 277), ('emissions', 270), ('efficiency', 262), ('heat', 262), ('european', 253), ('level', 251), ('target', 243), ('res', 241), ('programme', 240), ('share', 234), ('renewable', 231), ('year', 230), ('expected', 227), ('prices', 227), ('supply', 226), ('implementation', 217), ('final', 217), ('capacity', 216), ('including', 213), ('directive', 209), ('ministry', 203), ('accordance', 202), ('increase', 198), ('investment', 196), ('buildings', 195), ('calculation', 194), ('natural', 192), ('fuel', 192), ('industry', 191), ('period', 188), ('products', 185), ('financial', 184), ('based', 183), ('account', 180), ('within', 179), ('fuels', 179), ('act', 177), ('research', 176), ('climate', 175), ('price', 175), ('power', 175), ('regulation', 174), ('according', 169), ('policies', 168), ('public', 168), ('article', 164), ('verification', 164), ('czk', 163), ('non', 163), ('performance', 162), ('management', 162), ('growth', 160), ('infrastructure', 157), ('projects', 157), ('project', 156), ('term', 155), ('reduction', 154), ('regional', 154), ('distribution', 154), ('emission', 151), ('methodology', 149), ('supported', 147), ('number', 145), ('current', 144), ('used', 143), ('given', 143), ('oil', 142), ('long', 141), ('low', 141), ('area', 141), ('security', 140), ('sectors', 139), ('coal', 139)]

# %% [markdown]
# #### Get top words common across all 27 documents

# %% [markdown]
# After getting the CSV files for all the countries, we will get the intersection of the words across all the files to get the most common words in the documents

# %%
experiment1 =list_of_100words

# %%
all_top_words = []
for i in experiment1:
    for j in i:
        all_top_words.append(j)

# %%
all_top_words
# Out:
# [('energy', 1886),
#  ('electricity', 659),
#  ('gas', 618),
#  ('bulgaria', 524),
#  ('renewable', 475),
#  ('measures', 468),
#  ('national', 446),
#  ('sector', 432),
#  ('emissions', 394),
#  ('consumption', 373),
#  ('sources', 346),
#  ('eu', 322),
#  ('market', 317),
#  ('transport', 301),
#  ('efficiency', 296),
#  ('period', 286),
#  ('development', 259),
#  ('power', 252),
#  ('natural', 245),
#  ('transmission', 240),
#  ('including', 238),
#  ('capacity', 238),
#  ('final', 231),
#  ('generation', 229),
#  ('increase', 228),
#  ('plants', 227),
#  ('biomass', 205),
#  ('set', 202),
#  ('heating', 201),
#  ('buildings', 199),
#  ('policy', 198),
#  ('waste', 198),
#  ('projected', 197),
#  ('european', 197),
#  ('share', 193),
#  ('ktoe', 189),
#  ('implementation', 188),
#  ('fuels', 188),
#  ('plan', 184),
#  ('system', 179),
#  ('co', 176),
#  ('directive', 170),
#  ('ghg', 168),
#  ('project', 165),
#  ('heat', 153),
#  ('infrastructure', 150),
#  ('source', 145),
#  ('requirements', 145),
#  ('scenario', 144),
#  ('projects', 143),
#  ('existing', 142),
#  ('production', 137),
#  ('expected', 132),
#  ('compared', 131),
#  ('account', 130),
#  ('network', 130),
#  ('climate', 128),
#  ('supply', 127),
#  ('year', 127),
#  ('targets', 126),
#  ('systems', 125),
#  ('line', 125),
#  ('regulation', 125),
#  ('management', 120),
#  ('target', 119),
#  ('construction', 117),
#  ('accordance', 116),
#  ('area', 116),
#  ('model', 116),
#  ('public', 115),
#  ('change', 115),
#  ('sectors', 113),
#  ('consumers', 112),
#  ('ensure', 112),
#  ('modelling', 112),
#  ('reduction', 112),
#  ('union', 111),
#  ('following', 111),
#  ('support', 108),
#  ('programme', 108),
#  ('security', 107),
#  ('bulgarian', 106),
#  ('air', 104),
#  ('gwh', 104),
#  ('storage', 101),
#  ('distribution', 101),
#  ('eq', 100),
#  ('gross', 99),
#  ('projections', 99),
#  ('potential', 99),
#  ('regional', 97),
#  ('prices', 97),
#  ('table', 96),
#  ('level', 96),
#  ('article', 95),
#  ('building', 95),
#  ('used', 95),
#  ('est', 95),
#  ('policies', 92),
#  ('applicable', 92),
#  ('energy', 2811),
#  ('gas', 825),
#  ('electricity', 754),
#  ('poland', 657),
#  ('development', 641),
#  ('measures', 625),
#  ('transport', 556),
#  ('sector', 550),
#  ('power', 546),
#  ('scenario', 509),
#  ('ecp', 473),
#  ('national', 447),
#  ('production', 429),
#  ('consumption', 425),
#  ('system', 420),
#  ('market', 418),
#  ('table', 413),
#  ('policies', 408),
#  ('efficiency', 389),
#  ('fuel', 386),
#  ('capacity', 386),
#  ('emissions', 384),
#  ('heat', 377),
#  ('renewable', 369),
#  ('fuels', 368),
#  ('share', 350),
#  ('increase', 336),
#  ('sources', 333),
#  ('eu', 320),
#  ('transmission', 317),
#  ('including', 305),
#  ('heating', 303),
#  ('coal', 303),
#  ('final', 300),
#  ('generation', 298),
#  ('plants', 295),
#  ('natural', 293),
#  ('polish', 292),
#  ('ref', 274),
#  ('prices', 273),
#  ('res', 269),
#  ('support', 260),
#  ('necp', 257),
#  ('impact', 254),
#  ('sectors', 254),
#  ('technologies', 249),
#  ('demand', 246),
#  ('figure', 240),
#  ('source', 239),
#  ('infrastructure', 231),
#  ('european', 217),
#  ('emission', 212),
#  ('high', 211),
#  ('units', 211),
#  ('oil', 208),
#  ('existing', 207),
#  ('nuclear', 205),
#  ('economy', 204),
#  ('research', 203),
#  ('construction', 203),
#  ('co', 202),
#  ('based', 201),
#  ('level', 200),
#  ('potential', 200),
#  ('data', 198),
#  ('current', 196),
#  ('assessment', 196),
#  ('low', 194),
#  ('economic', 192),
#  ('projects', 191),
#  ('climate', 189),
#  ('million', 185),
#  ('projections', 185),
#  ('network', 183),
#  ('storage', 183),
#  ('gross', 177),
#  ('used', 173),
#  ('annex', 172),
#  ('well', 171),
#  ('eur', 171),
#  ('systems', 168),
#  ('expected', 168),
#  ('security', 167),
#  ('period', 167),
#  ('dimension', 167),
#  ('costs', 167),
#  ('industry', 165),
#  ('waste', 163),
#  ('implementation', 162),
#  ('non', 162),
#  ('areas', 161),
#  ('supply', 161),
#  ('buildings', 160),
#  ('end', 159),
#  ('changes', 155),
#  ('approx', 155),
#  ('year', 155),
#  ('district', 154),
#  ('policy', 153),
#  ('plan', 149),
#  ('energy', 1721),
#  ('national', 543),
#  ('electricity', 459),
#  ('plan', 379),
#  ('measures', 372),
#  ('romania', 359),
#  ('gas', 331),
#  ('climate', 327),
#  ('development', 315),
#  ('consumption', 299),
#  ('sector', 298),
#  ('renewable', 291),
#  ('market', 289),
#  ('eu', 282),
#  ('emissions', 256),
#  ('final', 255),
#  ('efficiency', 251),
#  ('system', 247),
#  ('natural', 239),
#  ('res', 230),
#  ('tegrated', 225),
#  ('transmission', 225),
#  ('transport', 223),
#  ('order', 220),
#  ('policies', 213),
#  ('production', 207),
#  ('capacity', 196),
#  ('increase', 191),
#  ('european', 183),
#  ('research', 179),
#  ('projects', 172),
#  ('level', 169),
#  ('sources', 162),
#  ('ghg', 157),
#  ('including', 151),
#  ('source', 150),
#  ('period', 143),
#  ('implementation', 142),
#  ('capacities', 141),
#  ('de', 137),
#  ('main', 132),
#  ('consumers', 132),
#  ('trend', 129),
#  ('following', 128),
#  ('commission', 125),
#  ('public', 122),
#  ('inecp', 121),
#  ('current', 120),
#  ('share', 116),
#  ('chart', 114),
#  ('reduction', 114),
#  ('support', 114),
#  ('based', 113),
#  ('dimension', 110),
#  ('security', 110),
#  ('kv', 110),
#  ('objectives', 105),
#  ('supply', 105),
#  ('storage', 105),
#  ('targets', 103),
#  ('scenario', 103),
#  ('decarbonisation', 102),
#  ('infrastructure', 102),
#  ('table', 99),
#  ('target', 99),
#  ('industrial', 98),
#  ('innovation', 97),
#  ('projected', 97),
#  ('smart', 96),
#  ('million', 95),
#  ('eur', 94),
#  ('technologies', 93),
#  ('power', 92),
#  ('investments', 92),
#  ('regulation', 92),
#  ('systems', 91),
#  ('ministry', 91),
#  ('moreover', 91),
#  ('price', 89),
#  ('heating', 87),
#  ('context', 86),
#  ('demand', 86),
#  ('heat', 84),
#  ('buildings', 83),
#  ('strategy', 82),
#  ('environment', 82),
#  ('project', 82),
#  ('member', 81),
#  ('accordance', 81),
#  ('impact', 79),
#  ('ro', 79),
#  ('existing', 77),
#  ('costs', 77),
#  ('developing', 77),
#  ('directive', 77),
#  ('regarding', 76),
#  ('carbon', 76),
#  ('compared', 76),
#  ('transition', 75),
#  ('investment', 75),
#  ('energy', 1594),
#  ('climate', 657),
#  ('gas', 504),
#  ('netherlands', 461),
#  ('national', 349),
#  ('electricity', 345),
#  ('co', 327),
#  ('emissions', 320),
#  ('renewable', 319),
#  ('policy', 305),
#  ('agreement', 291),
#  ('measures', 263),
#  ('market', 232),
#  ('consumption', 228),
#  ('plan', 224),
#  ('expected', 216),
#  ('policies', 200),
#  ('reduction', 179),
#  ('environment', 178),
#  ('supply', 172),
#  ('savings', 171),
#  ('government', 170),
#  ('innovation', 168),
#  ('increase', 167),
#  ('integrated', 166),
#  ('european', 158),
#  ('sector', 154),
#  ('investments', 151),
#  ('built', 150),
#  ('greenhouse', 146),
#  ('pbl', 142),
#  ('including', 139),
#  ('due', 138),
#  ('industry', 135),
#  ('heat', 135),
#  ('sustainable', 133),
#  ('target', 131),
#  ('based', 131),
#  ('natural', 131),
#  ('system', 130),
#  ('dutch', 126),
#  ('years', 123),
#  ('price', 122),
#  ('wind', 121),
#  ('demand', 120),
#  ('related', 119),
#  ('see', 119),
#  ('transition', 114),
#  ('generation', 114),
#  ('development', 114),
#  ('result', 111),
#  ('countries', 110),
#  ('per', 110),
#  ('period', 109),
#  ('tax', 107),
#  ('costs', 106),
#  ('sectors', 106),
#  ('transport', 104),
#  ('regional', 102),
#  ('capacity', 101),
#  ('level', 101),
#  ('high', 101),
#  ('figure', 101),
#  ('power', 98),
#  ('kev', 97),
#  ('megatons', 97),
#  ('addition', 96),
#  ('share', 96),
#  ('decrease', 96),
#  ('sources', 95),
#  ('low', 95),
#  ('production', 94),
#  ('equivalents', 91),
#  ('growth', 91),
#  ('year', 88),
#  ('economic', 87),
#  ('approach', 87),
#  ('petajoules', 87),
#  ('emission', 86),
#  ('research', 84),
#  ('number', 84),
#  ('targets', 83),
#  ('achieve', 83),
#  ('eu', 83),
#  ('important', 83),
#  ('adopted', 81),
#  ('term', 81),
#  ('mobility', 81),
#  ('buildings', 80),
#  ('households', 80),
#  ('effects', 79),
#  ('available', 79),
#  ('euros', 79),
#  ('document', 78),
#  ('cost', 78),
#  ('prices', 78),
#  ('small', 78),
#  ('used', 77),
#  ('consumers', 77),
#  ('security', 76),
#  ('energy', 1563),
#  ('gas', 576),
#  ('consumption', 555),
#  ('electricity', 516),
#  ('hungary', 402),
#  ('market', 395),
#  ('hungarian', 385),
#  ('renewable', 361),
#  ('natural', 296),
#  ('system', 270),
#  ('transport', 254),
#  ('based', 249),
#  ('figure', 247),
#  ('measures', 238),
#  ('power', 232),
#  ('national', 231),
#  ('sector', 230),
#  ('share', 225),
#  ('increase', 215),
#  ('european', 213),
#  ('production', 210),
#  ('data', 204),
#  ('supply', 197),
#  ('sources', 186),
#  ('capacity', 182),
#  ('emissions', 178),
#  ('development', 175),
#  ('eu', 173),
#  ('capacities', 173),
#  ('efficiency', 169),
#  ('within', 163),
#  ('final', 162),
#  ('source', 158),
#  ('network', 151),
#  ('security', 134),
#  ('demand', 129),
#  ('storage', 129),
#  ('climate', 127),
#  ('necessary', 127),
#  ('heating', 125),
#  ('projects', 124),
#  ('level', 123),
#  ('relation', 121),
#  ('regulation', 121),
#  ('scenario', 120),
#  ('wam', 119),
#  ('expected', 118),
#  ('wem', 118),
#  ('may', 118),
#  ('https', 115),
#  ('cost', 113),
#  ('hu', 113),
#  ('generation', 112),
#  ('point', 111),
#  ('price', 110),
#  ('nuclear', 110),
#  ('ktoe', 109),
#  ('plan', 108),
#  ('plant', 108),
#  ('heat', 108),
#  ('table', 106),
#  ('year', 105),
#  ('change', 103),
#  ('innovation', 101),
#  ('prices', 99),
#  ('period', 99),
#  ('chapter', 97),
#  ('costs', 95),
#  ('transmission', 94),
#  ('policy', 94),
#  ('en', 94),
#  ('support', 94),
#  ('industrial', 93),
#  ('ghg', 91),
#  ('policies', 90),
#  ('including', 90),
#  ('number', 90),
#  ('sectors', 89),
#  ('import', 89),
#  ('technologies', 89),
#  ('retail', 88),
#  ('relating', 88),
#  ('implementation', 88),
#  ('significantly', 88),
#  ('co', 87),
#  ('high', 87),
#  ('markets', 85),
#  ('billion', 84),
#  ('directive', 84),
#  ('buildings', 83),
#  ('research', 82),
#  ('million', 82),
#  ('eurostat', 82),
#  ('distribution', 81),
#  ('services', 81),
#  ('border', 79),
#  ('oil', 78),
#  ('industry', 78),
#  ('plants', 78),
#  ('additional', 78),
#  ('energy', 1764),
#  ('national', 709),
#  ('plan', 562),
#  ('measures', 496),
#  ('sector', 478),
#  ('electricity', 469),
#  ('climate', 429),
#  ('december', 408),
#  ('gas', 384),
#  ('development', 382),
#  ('integrated', 379),
#  ('consumption', 357),
#  ('italy', 346),
#  ('transport', 334),
#  ('renewable', 334),
#  ('efficiency', 322),
#  ('system', 317),
#  ('market', 290),
#  ('production', 269),
#  ('including', 260),
#  ('network', 247),
#  ('public', 244),
#  ('decree', 238),
#  ('emissions', 230),
#  ('economic', 229),
#  ('plants', 228),
#  ('sources', 216),
#  ('systems', 214),
#  ('res', 209),
#  ('increase', 204),
#  ('law', 201),
#  ('million', 197),
#  ('policies', 190),
#  ('power', 178),
#  ('order', 175),
#  ('eu', 172),
#  ('european', 170),
#  ('buildings', 167),
#  ('research', 165),
#  ('scenario', 163),
#  ('storage', 162),
#  ('infrastructure', 160),
#  ('year', 159),
#  ('environmental', 157),
#  ('sectors', 155),
#  ('reduction', 154),
#  ('italian', 154),
#  ('objectives', 153),
#  ('set', 153),
#  ('resources', 152),
#  ('services', 148),
#  ('used', 148),
#  ('renewables', 147),
#  ('target', 146),
#  ('existing', 145),
#  ('following', 145),
#  ('table', 144),
#  ('non', 142),
#  ('article', 142),
#  ('terms', 140),
#  ('supply', 139),
#  ('capacity', 138),
#  ('heating', 138),
#  ('targets', 136),
#  ('areas', 134),
#  ('particular', 133),
#  ('demand', 131),
#  ('projects', 131),
#  ('support', 129),
#  ('potential', 127),
#  ('ministry', 126),
#  ('vehicles', 126),
#  ('current', 125),
#  ('final', 125),
#  ('generation', 124),
#  ('level', 123),
#  ('source', 122),
#  ('period', 120),
#  ('inecp', 118),
#  ('made', 118),
#  ('years', 114),
#  ('end', 114),
#  ('around', 114),
#  ('basis', 113),
#  ('waste', 113),
#  ('security', 112),
#  ('impact', 111),
#  ('natural', 109),
#  ('technologies', 109),
#  ('local', 109),
#  ('expected', 109),
#  ('regulation', 108),
#  ('electric', 108),
#  ('heat', 105),
#  ('part', 104),
#  ('possible', 102),
#  ('fuels', 102),
#  ('figure', 101),
#  ('share', 100),
#  ('directive', 99),
#  ('energy', 1871),
#  ('res', 661),
#  ('measures', 504),
#  ('electricity', 501),
#  ('consumption', 463),
#  ('development', 398),
#  ('policy', 385),
#  ('sector', 383),
#  ('final', 329),
#  ('gas', 317),
#  ('generation', 311),
#  ('efficiency', 282),
#  ('objective', 281),
#  ('power', 268),
#  ('transport', 268),
#  ('market', 264),
#  ('measure', 258),
#  ('national', 246),
#  ('objectives', 240),
#  ('system', 237),
#  ('systems', 228),
#  ('emissions', 218),
#  ('climate', 216),
#  ('period', 210),
#  ('implementation', 208),
#  ('greece', 206),
#  ('plants', 204),
#  ('increase', 197),
#  ('share', 194),
#  ('regulatory', 189),
#  ('chart', 181),
#  ('necp', 179),
#  ('economic', 178),
#  ('framework', 178),
#  ('policies', 169),
#  ('natural', 168),
#  ('projects', 166),
#  ('storage', 164),
#  ('specific', 160),
#  ('context', 156),
#  ('sectors', 156),
#  ('buildings', 153),
#  ('promoting', 152),
#  ('domestic', 152),
#  ('management', 151),
#  ('technologies', 147),
#  ('well', 144),
#  ('actions', 143),
#  ('eu', 143),
#  ('public', 140),
#  ('reduction', 138),
#  ('article', 135),
#  ('table', 135),
#  ('expected', 134),
#  ('economy', 133),
#  ('vehicles', 131),
#  ('change', 128),
#  ('compared', 127),
#  ('improvement', 127),
#  ('heating', 125),
#  ('plan', 123),
#  ('areas', 120),
#  ('support', 120),
#  ('penetration', 118),
#  ('necessary', 115),
#  ('priorities', 114),
#  ('key', 109),
#  ('account', 109),
#  ('supply', 109),
#  ('financing', 108),
#  ('greek', 105),
#  ('planning', 105),
#  ('following', 104),
#  ('cost', 103),
#  ('operation', 103),
#  ('capacity', 103),
#  ('sustainable', 102),
#  ('lignite', 102),
#  ('technical', 101),
#  ('interconnection', 100),
#  ('evolution', 100),
#  ('level', 99),
#  ('particular', 98),
#  ('waste', 98),
#  ('relevant', 98),
#  ('high', 98),
#  ('financial', 98),
#  ('transition', 96),
#  ('contribution', 94),
#  ('reducing', 93),
#  ('year', 93),
#  ('infrastructure', 92),
#  ('existing', 92),
#  ('order', 88),
#  ('cooling', 87),
#  ('products', 87),
#  ('significant', 87),
#  ('ghg', 86),
#  ('fuel', 85),
#  ('programmes', 84),
#  ('energy', 1181),
#  ('denmark', 470),
#  ('danish', 334),
#  ('electricity', 331),
#  ('gas', 304),
#  ('climate', 241),
#  ('measures', 205),
#  ('sector', 190),
#  ('renewable', 189),
#  ('emissions', 186),
#  ('agreement', 186),
#  ('nordic', 178),
#  ('market', 177),
#  ('consumption', 170),
#  ('wind', 169),
#  ('heating', 162),
#  ('national', 156),
#  ('production', 146),
#  ('system', 143),
#  ('heat', 140),
#  ('green', 137),
#  ('projects', 137),
#  ('support', 136),
#  ('government', 129),
#  ('expected', 127),
#  ('plan', 126),
#  ('eu', 124),
#  ('supply', 122),
#  ('development', 120),
#  ('share', 120),
#  ('policies', 116),
#  ('efficiency', 113),
#  ('including', 113),
#  ('figure', 106),
#  ('biomass', 106),
#  ('based', 105),
#  ('increase', 104),
#  ('dkk', 103),
#  ('research', 101),
#  ('power', 101),
#  ('transport', 100),
#  ('countries', 98),
#  ('security', 96),
#  ('target', 94),
#  ('level', 94),
#  ('offshore', 94),
#  ('cooperation', 93),
#  ('well', 92),
#  ('district', 87),
#  ('point', 87),
#  ('information', 85),
#  ('price', 82),
#  ('regulation', 81),
#  ('capacity', 80),
#  ('public', 80),
#  ('buildings', 76),
#  ('technology', 76),
#  ('policy', 75),
#  ('targets', 73),
#  ('scheme', 73),
#  ('grid', 73),
#  ('greenhouse', 72),
#  ('single', 71),
#  ('transition', 69),
#  ('natural', 69),
#  ('section', 68),
#  ('technologies', 68),
#  ('shows', 68),
#  ('project', 68),
#  ('part', 67),
#  ('objectives', 67),
#  ('action', 65),
#  ('set', 65),
#  ('existing', 64),
#  ('sectors', 64),
#  ('tax', 64),
#  ('sources', 62),
#  ('year', 61),
#  ('large', 61),
#  ('land', 61),
#  ('related', 60),
#  ('parties', 60),
#  ('initiatives', 60),
#  ('future', 60),
#  ('demand', 60),
#  ('period', 59),
#  ('years', 59),
#  ('ets', 58),
#  ('act', 58),
#  ('final', 58),
#  ('north', 57),
#  ('towards', 56),
#  ('oil', 56),
#  ('council', 54),
#  ('used', 54),
#  ('order', 54),
#  ('lulucf', 54),
#  ('data', 54),
#  ('june', 53),
#  ('see', 53),
#  ('energy', 1203),
#  ('measures', 403),
#  ('estonia', 385),
#  ('electricity', 335),
#  ('sector', 313),
#  ('development', 312),
#  ('system', 280),
#  ('gas', 277),
#  ('renewable', 274),
#  ('emissions', 235),
#  ('climate', 224),
#  ('plan', 220),
#  ('consumption', 208),
#  ('eu', 195),
#  ('transport', 189),
#  ('market', 187),
#  ('estonian', 187),
#  ('impact', 184),
#  ('national', 160),
#  ('baltic', 157),
#  ('production', 144),
#  ('https', 144),
#  ('efficiency', 141),
#  ('measure', 135),
#  ('states', 132),
#  ('increase', 129),
#  ('ghg', 127),
#  ('security', 126),
#  ('targets', 125),
#  ('supply', 124),
#  ('table', 117),
#  ('heating', 115),
#  ('support', 114),
#  ('change', 108),
#  ('area', 108),
#  ('share', 108),
#  ('transmission', 108),
#  ('buildings', 106),
#  ('fuels', 103),
#  ('policies', 102),
#  ('figure', 100),
#  ('network', 100),
#  ('carbon', 98),
#  ('act', 97),
#  ('final', 95),
#  ('including', 95),
#  ('target', 95),
#  ('public', 95),
#  ('fuel', 94),
#  ('environmental', 93),
#  ('policy', 91),
#  ('increasing', 91),
#  ('additional', 90),
#  ('activities', 89),
#  ('research', 88),
#  ('oil', 85),
#  ('according', 84),
#  ('price', 84),
#  ('power', 82),
#  ('local', 81),
#  ('waste', 81),
#  ('reduction', 80),
#  ('natural', 80),
#  ('electrical', 78),
#  ('air', 77),
#  ('wind', 77),
#  ('level', 77),
#  ('renovation', 77),
#  ('ndpes', 76),
#  ('european', 74),
#  ('see', 74),
#  ('efficient', 74),
#  ('cooperation', 73),
#  ('sectors', 73),
#  ('period', 73),
#  ('capacity', 73),
#  ('related', 71),
#  ('based', 71),
#  ('economy', 71),
#  ('used', 71),
#  ('sources', 71),
#  ('objectives', 70),
#  ('co', 70),
#  ('planned', 69),
#  ('economic', 69),
#  ('shale', 69),
#  ('projects', 69),
#  ('kv', 68),
#  ('necp', 67),
#  ('regulation', 67),
#  ('projections', 67),
#  ('government', 66),
#  ('implementation', 66),
#  ('following', 65),
#  ('incl', 65),
#  ('land', 64),
#  ('project', 64),
#  ('areas', 63),
#  ('generation', 62),
#  ('services', 61),
#  ('energy', 1430),
#  ('slovenia', 737),
#  ('electricity', 515),
#  ('climate', 441),
#  ('nepn', 429),
#  ('measures', 407),
#  ('development', 358),
#  ('national', 356),
#  ('gas', 353),
#  ('scenario', 347),
#  ('consumption', 336),
#  ('plan', 316),
#  ('figure', 312),
#  ('transport', 294),
#  ('republic', 292),
#  ('res', 283),
#  ('integrated', 262),
#  ('sector', 259),
#  ('emissions', 257),
#  ('production', 230),
#  ('system', 229),
#  ('share', 225),
#  ('implementation', 214),
#  ('existing', 200),
#  ('renewable', 199),
#  ('market', 195),
#  ('power', 195),
#  ('natural', 176),
#  ('buildings', 174),
#  ('heat', 168),
#  ('increase', 167),
#  ('table', 167),
#  ('public', 163),
#  ('eu', 159),
#  ('network', 159),
#  ('final', 158),
#  ('incentives', 153),
#  ('transmission', 151),
#  ('ktoe', 151),
#  ('op', 143),
#  ('distribution', 140),
#  ('key', 138),
#  ('supply', 135),
#  ('period', 134),
#  ('efficiency', 129),
#  ('economic', 127),
#  ('projects', 126),
#  ('area', 126),
#  ('sources', 125),
#  ('fuels', 123),
#  ('additional', 121),
#  ('technologies', 119),
#  ('ghg', 118),
#  ('systems', 111),
#  ('environmental', 111),
#  ('plants', 110),
#  ('em', 107),
#  ('infrastructure', 106),
#  ('account', 106),
#  ('gwh', 106),
#  ('industry', 105),
#  ('including', 102),
#  ('financial', 100),
#  ('waste', 100),
#  ('heating', 99),
#  ('investment', 99),
#  ('sectors', 97),
#  ('change', 96),
#  ('sustainable', 96),
#  ('instrument', 96),
#  ('generation', 94),
#  ('renovation', 92),
#  ('mzi', 92),
#  ('services', 91),
#  ('tgp', 91),
#  ('scenarios', 90),
#  ('wood', 89),
#  ('accordance', 87),
#  ('price', 87),
#  ('construction', 87),
#  ('slovenian', 87),
#  ('targets', 85),
#  ('prices', 85),
#  ('least', 83),
#  ('capacity', 83),
#  ('compared', 82),
#  ('research', 81),
#  ('target', 81),
#  ('level', 80),
#  ('year', 79),
#  ('increasing', 79),
#  ('biomass', 78),
#  ('expected', 77),
#  ('support', 77),
#  ('european', 77),
#  ('instruments', 77),
#  ('ensure', 77),
#  ('areas', 76),
#  ('impact', 76),
#  ('source', 76),
#  ...]

# %%
df_all_words = pd.DataFrame(all_top_words, columns=['Word', 'Count'])

# %%
words_occurance_in_documents=df_all_words.groupby('Word').agg({'Count':'count'}).sort_values(by='Count', ascending=False)

# %%
len(words_occurance_in_documents)
# Out:
# 482

# %% [markdown]
# From 2500 words the we just got 482 words in Union

# %%
word_occuring_in_all_documents = words_occurance_in_documents[words_occurance_in_documents['Count']==27].reset_index()

# %%
word_occuring_in_all_documents
# Out:
#            Word  Count
# 0       climate     27
# 1      national     27
# 2        market     27
# 3      measures     27
# 4     emissions     27
# 5   electricity     27
# 6      increase     27
# 7        sector     27
# 8     transport     27
# 9        energy     27
# 10          gas     27
# 11  consumption     27
# 12         plan     27
# 13  development     27

# %%
os.chdir(output_data_location)
word_occuring_in_all_documents.to_csv('most_common_new.csv', index=False)

# %% [markdown]
# #### Creating a summary table to summarize the information created

# %%
information_100
# Out:
# [['Document', 'Page_Count', 'Count_Total_Words', 'Top_Count', 'Ratio'],
#  ['bg_final_necp_main_en_0', 280, 56046, 20395, 36.38975127573779],
#  ['pl_final_necp_main_en_0', 401, 94910, 30715, 32.36223790959857],
#  ['ro_final_necp_main_en_0', 228, 49203, 17148, 34.85153344308274],
#  ['nl_final_necp_main_en_0', 170, 49502, 16034, 32.39061048038463],
#  ['hu_final_necp_main_en_0', 305, 50472, 16767, 33.22039942938659],
#  ['it_final_necp_main_en_0', 329, 70542, 21051, 29.84179637662669],
#  ['el_final_necp_main_en_0', 335, 52848, 19056, 36.05812897366031],
#  ['dk_final_necp_main_en_0', 184, 35179, 11784, 33.49725688621052],
#  ['ee_final_necp_main_en_0', 195, 37568, 13004, 34.61456558773424],
#  ['si_final_necp_main_en_0', 236, 47545, 17664, 37.1521716268798],
#  ['at_final_necp_main_en_0', 268, 47520, 16037, 33.747895622895626],
#  ['fi_final_necp_main_en_0', 183, 28365, 11140, 39.27375286444562],
#  ['fr_final_necp_main_en_0', 328, 67002, 19957, 29.785678039461512],
#  ['ie_final_necp_main_en_0', 273, 49421, 15986, 32.34657331903442],
#  ['cy_final_necp_main_en_0', 302, 50887, 16831, 33.07524515102089],
#  ['de_final_necp_main_en_0', 262, 77101, 24698, 32.033306960999205],
#  ['es_final_necp_main_en_0', 425, 90459, 28132, 31.09917200057485],
#  ['sk_final_necp_main_en_0', 252, 57955, 18479, 31.885083254248986],
#  ['be_final_necp_main_en_0', 476, 123095, 33569, 27.270807100207158],
#  ['se_final_necp_main_en_0', 199, 38656, 13453, 34.80184188741722],
#  ['pt_final_necp_main_en_0', 198, 53062, 17826, 33.594662847235305],
#  ['mt_final_necp_main_en_0', 258, 51412, 16745, 32.57021706994476],
#  ['lu_final_necp_main_en_0', 190, 34424, 12285, 35.68731117824773],
#  ['lv_final_necp_main_en_0', 176, 39032, 13508, 34.60750153720025],
#  ['hr_final_necp_main_en_0', 240, 50064, 18200, 36.35346756152125],
#  ['lt_final_necp_main_en_0', 273, 56990, 20338, 35.686962625021934],
#  ['cs_final_necp_main_en_0', 442, 84935, 29445, 34.66768705480662]]

# %%
df = pd.DataFrame(information_100, columns=information_100.pop(0))
df.to_csv('Information_100word_count.csv', index=False)

# %%
df
# Out:
#                    Document  Page_Count  Count_Total_Words  Top_Count  \
# 0   bg_final_necp_main_en_0         280              56046      20395
# 1   pl_final_necp_main_en_0         401              94910      30715
# 2   ro_final_necp_main_en_0         228              49203      17148
# 3   nl_final_necp_main_en_0         170              49502      16034
# 4   hu_final_necp_main_en_0         305              50472      16767
# 5   it_final_necp_main_en_0         329              70542      21051
# 6   el_final_necp_main_en_0         335              52848      19056
# 7   dk_final_necp_main_en_0         184              35179      11784
# 8   ee_final_necp_main_en_0         195              37568      13004
# 9   si_final_necp_main_en_0         236              47545      17664
# 10  at_final_necp_main_en_0         268              47520      16037
# 11  fi_final_necp_main_en_0         183              28365      11140
# 12  fr_final_necp_main_en_0         328              67002      19957
# 13  ie_final_necp_main_en_0         273              49421      15986
# 14  cy_final_necp_main_en_0         302              50887      16831
# 15  de_final_necp_main_en_0         262              77101      24698
# 16  es_final_necp_main_en_0         425              90459      28132
# 17  sk_final_necp_main_en_0         252              57955      18479
# 18  be_final_necp_main_en_0         476             123095      33569
# 19  se_final_necp_main_en_0         199              38656      13453
# 20  pt_final_necp_main_en_0         198              53062      17826
# 21  mt_final_necp_main_en_0         258              51412      16745
# 22  lu_final_necp_main_en_0         190              34424      12285
# 23  lv_final_necp_main_en_0         176              39032      13508
# 24  hr_final_necp_main_en_0         240              50064      18200
# 25  lt_final_necp_main_en_0         273              56990      20338
# 26  cs_final_necp_main_en_0         442              84935      29445
#
#         Ratio
# 0   36.389751
# 1   32.362238
# 2   34.851533
# 3   32.390610
# 4   33.220399
# 5   29.841796
# 6   36.058129
# 7   33.497257
# 8   34.614566
# 9   37.152172
# 10  33.747896
# 11  39.273753
# 12  29.785678
# 13  32.346573
# 14  33.075245
# 15  32.033307
# 16  31.099172
# 17  31.885083
# 18  27.270807
# 19  34.801842
# 20  33.594663
# 21  32.570217
# 22  35.687311
# 23  34.607502
# 24  36.353468
# 25  35.686963
# 26  34.667687

# %% [markdown]
# we can see that on an avg. the top 100 words give a 33% coverage of the document

# %% [markdown]
# ## Part 2: Exploratory Data Analysis

# %% [markdown]
# ### 2a. Generate a word cloud

# %% [markdown]
# Get all the words across the all the NECPs and plot a word clous of the frequently occurring words

# %%
def generate_wordcloud(all_necps_filepath,necps_names, text):
    for necp, necp_name in zip(all_necps_filepath,necps_names):
        count =0
        pdfFileObj = open(necp, 'rb')
        pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
        num_pages = pdfReader.numPages
        while count < num_pages:
            pageObj = pdfReader.getPage(count)
            count += 1
            text += pageObj.extractText()
    return text

# %%
os.chdir(input_data_location)
text=''
all_text = generate_wordcloud(all_necps_filepath,necps_names, text)

# %%
common_words=''
tokens = word_tokenize(all_text)
# Remove single-character tokens (mostly punctuation)
tokens = [word for word in tokens if len(word) > 1]
punctuations = ['(', ')', ';', ':', '[', ']', ',', '.']
# We initialize the stopwords variable, which is a list of words like "The," "I," "and," etc. that don't hold much
# value as keywords.
stop_words = stopwords.words('english')
also_stop_words = ['also', 'total', 'use', 'new']
total_stop_words = stop_words + also_stop_words
# We create a list comprehension that only returns a list of words that are NOT IN stop_words and NOT IN punctuations.
keywords = [word for word in tokens if not word.lower() in total_stop_words and not word in punctuations]
keywords = [i for i in keywords if i.isalpha()]
common_words += " ".join(keywords)+" "

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(common_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

# %% [markdown]
# ### 2b. Analysis on Plurals

# %% [markdown]
# To analyze the relationship of the vectorized words and their pulral forms

# %% [markdown]
# We load Google's pre-trained word2vec model to vectorize every word into a vector of size 300

# %%
model = KeyedVectors.load_word2vec_format(vector_location, binary=True) #loading a pre-trained Google embedding model

# %% [markdown]
# From the following statement we can see that the vector of singular form of the word is not equal to its plural form

# %%
(model['nation']==model['Nations']).all()
# Out:
# False

# %% [markdown]
# We will load the file containing all the words and their plural forms

# %%
plural = pd.read_csv(r'/home/bhawna/text_analytics/Gender_Dimension/output_new/most_common_plurals.csv')

# %% [markdown]
# There are some words in the file which have no plural forms, therefore only the words which have plural are taken into consideration

# %%
plural=plural[:11]

# %% [markdown]
# We compute the similarity of the vectorized word and it's plural by taking pairs from all the words occurring in the male list and the female list
#
# - Male List = {man, male, he, father}
# - Female List = {woman, female, she, mother}

# %%
plural['man_singular']=plural['Word'].apply(lambda x: model.similarity("man", x))
plural['man_plural']=plural['Word plural'].apply(lambda x: model.similarity("man", x))
plural['woman_singular']=plural['Word'].apply(lambda x: model.similarity("woman", x))
plural['woman_plural']=plural['Word plural'].apply(lambda x: model.similarity("woman", x))
plural['male_singular']=plural['Word'].apply(lambda x: model.similarity("male", x))
plural['male_plural']=plural['Word plural'].apply(lambda x: model.similarity("male", x))
plural['female_singular']=plural['Word'].apply(lambda x: model.similarity("female", x))
plural['female_plural']=plural['Word plural'].apply(lambda x: model.similarity("female", x))
plural['he_singular']=plural['Word'].apply(lambda x: model.similarity("he", x))
plural['he_plural']=plural['Word plural'].apply(lambda x: model.similarity("he", x))
plural['she_singular']=plural['Word'].apply(lambda x: model.similarity("she", x))
plural['she_plural']=plural['Word plural'].apply(lambda x: model.similarity("she", x))
plural['father_singular']=plural['Word'].apply(lambda x: model.similarity("father", x))
plural['father_plural']=plural['Word plural'].apply(lambda x: model.similarity("father", x))
plural['mother_singular']=plural['Word'].apply(lambda x: model.similarity("mother", x))
plural['mother_plural']=plural['Word plural'].apply(lambda x: model.similarity("mother", x))

# %%
plural
# Out:
#            Word   Word plural  man_singular  man_plural  woman_singular  \
# 0       measure      measures      0.048255   -0.020671        0.031771
# 1     transport    transports      0.017236   -0.011595       -0.002930
# 2        sector       sectors      0.035529   -0.005908        0.037509
# 3      emission     emissions      0.018873    0.022088        0.003689
# 4        market       markets      0.009960   -0.023517        0.035628
# 5      increase     increases      0.015664   -0.012746        0.025839
# 6      national     nationals      0.084865    0.182780        0.059047
# 7   development  developments      0.005971   -0.032102       -0.003670
# 8        energy      energies      0.023201    0.006714       -0.009654
# 9           gas         gases      0.094566    0.063358        0.092870
# 10         plan         plans      0.091049    0.000024        0.036240
#
#     woman_plural  male_singular  male_plural  female_singular  female_plural  \
# 0      -0.012342       0.119952     0.037194         0.069007       0.020425
# 1       0.005754      -0.002699     0.057844         0.033222       0.072054
# 2      -0.003714       0.060956     0.047032         0.039395       0.028880
# 3      -0.001675      -0.054332    -0.044296        -0.064881      -0.063424
# 4       0.013899       0.068375    -0.022209         0.010918      -0.069894
# 5       0.022458       0.097062     0.065570         0.099465       0.053769
# 6       0.203086       0.114352     0.165558         0.175138       0.192273
# 7       0.010199       0.002864    -0.052157        -0.000921      -0.034345
# 8      -0.014238      -0.037055     0.045702        -0.020291       0.045154
# 9       0.027061      -0.022441    -0.001126        -0.030444      -0.005248
# 10     -0.009117       0.011969    -0.038658        -0.025584      -0.033882
#
#     he_singular  he_plural  she_singular  she_plural  father_singular  \
# 0      0.127575   0.060263      0.077946    0.037171         0.017602
# 1      0.042974   0.007233      0.028554    0.020729        -0.018361
# 2      0.056744   0.001565      0.039776    0.004064         0.017494
# 3      0.009978   0.016047     -0.008070   -0.031413         0.009731
# 4      0.049706   0.027990      0.031778    0.040863        -0.022881
# 5      0.072060   0.041460      0.054007    0.067325        -0.021039
# 6      0.122506   0.110169      0.090269    0.130696         0.131019
# 7      0.046820   0.056379     -0.009279    0.022128         0.048321
# 8      0.129028   0.064431      0.086615    0.071580         0.016673
# 9      0.121561   0.045860      0.112119    0.025612         0.056648
# 10     0.169378   0.145384      0.070713    0.086242         0.058034
#
#     father_plural  mother_singular  mother_plural
# 0        0.041376         0.016745       0.015107
# 1       -0.047385         0.018252      -0.022506
# 2       -0.013418        -0.005521      -0.049529
# 3        0.028203         0.014585       0.025505
# 4       -0.017851        -0.014812      -0.000711
# 5       -0.061144         0.011106       0.003329
# 6        0.106261         0.063348       0.141091
# 7        0.045374         0.031178       0.030497
# 8        0.101353         0.004089       0.062429
# 9        0.022701         0.067677       0.027071
# 10       0.080577         0.057933       0.070340

# %% [markdown]
# Since the table is not clear we plot some charts to look into the values

# %% [markdown]
# #### Following piece of the code will generate distances of the energy words (both singular and form) with the male words

# %%
man_data = plural[['Word', 'man_singular', 'man_plural']].set_index('Word')
plt.figure(figsize=(8,5)) 
man_data.plot(kind='bar', stacked= True, color=['red', 'pink'])
plt.title('Distance comparision for words with man')
plt.xlabel('Words')
plt.ylabel('Distance')
male_data = plural[['Word', 'male_singular', 'male_plural']].set_index('Word')
male_data.plot(kind='bar', stacked= True, color=['red', 'pink'])
plt.title('Distance comparision for words with male')
plt.xlabel('Words')
plt.ylabel('Distance')
he_data = plural[['Word', 'he_singular', 'he_plural']].set_index('Word')
he_data.plot(kind='bar', stacked= True, color=['red', 'pink'])
plt.title('Distance comparision for words with he')
plt.xlabel('Words')
plt.ylabel('Distance')
father_data = plural[['Word', 'father_singular', 'father_plural']].set_index('Word')
father_data.plot(kind='bar', stacked= True, color=['red', 'pink'])
plt.title('Distance comparision for words with father')
plt.xlabel('Words')
plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')

# %% [markdown]
# The graphs indicate that the stacked bars are not equal, indicating that the distance measure or the similarity metric of the word and its plurl form is different and not the same in case of the male words.

# %%
woman_data = plural[['Word', 'woman_singular', 'woman_plural']].set_index('Word')
plt.figure(figsize=(8,5)) 
woman_data.plot(kind='bar', stacked= True, color=['red', 'pink'])
plt.title('Distance comparision for words with WOMAN')
plt.xlabel('Words')
plt.ylabel('Distance')
female_data = plural[['Word', 'female_singular', 'female_plural']].set_index('Word')
female_data.plot(kind='bar', stacked= True, color=['red', 'pink'])
plt.title('Distance comparision for words with FEMALE')
plt.xlabel('Words')
plt.ylabel('Distance')
she_data = plural[['Word', 'she_singular', 'she_plural']].set_index('Word')
she_data.plot(kind='bar', stacked= True, color=['red', 'pink'])
plt.title('Distance comparision for words with SHE')
plt.xlabel('Words')
plt.ylabel('Distance')
mother_data = plural[['Word', 'mother_singular', 'mother_plural']].set_index('Word')
mother_data.plot(kind='bar', stacked= True, color=['red', 'pink'])
plt.title('Distance comparision for words with MOTHER')
plt.xlabel('Words')
plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')

# %% [markdown]
# The graphs indicate that the stacked bars are not equal, indicating that the distance measure or the similarity metric of the word and its plurl form is different and not the same in case of the female words.

# %% [markdown]
# #### Overall comparision of the distances : Histogram

# %%
sns.histplot(plural['man_singular'], color='red' )
sns.histplot(plural['man_plural'], color='green')
# Out:
# <AxesSubplot:xlabel='man_singular', ylabel='Count'>

# %%
sns.histplot(plural['woman_singular'], color='red' )
sns.histplot(plural['woman_plural'], color='green')
# Out:
# <AxesSubplot:xlabel='woman_singular', ylabel='Count'>

# %% [markdown]
# The following code for generates the Word Embedding graph for all the words commonly occuring in the member states and the basic male and femaale words ['he', 'man', 'male', 'father'] and the counterpart

# %% [markdown]
# The code typically calculates PCA on the 300 vector size and then plot those components in 2D

# %% [markdown]
# ### 2C. Plotting the word embeddings in general context

# %% [markdown]
# Looking into the relationship b/w {'Man', 'Woman', 'Engineer', 'Nurse'}

# %%
words = {'Man', 'Woman', 'Engineer', 'Nurse'}

# %%
dict_words_vector={}
for word in words:
    dict_words_vector[word] = model[word]
    
all_values=[]
for key,values in dict_words_vector.items():
    all_values.append(values)

# %%
new=pd.DataFrame(all_values)
new.index=words

# %%
new
# Out:
#                0         1         2         3         4         5    \
# Nurse    -0.076660 -0.080566  0.181641 -0.016968  0.019165  0.204102
# Engineer -0.149414 -0.108887  0.022583 -0.261719 -0.304688  0.168945
# Woman     0.281250  0.061279 -0.149414 -0.153320  0.462891 -0.239258
# Man       0.103516  0.089844 -0.047852  0.022461  0.213867 -0.042725
#
#                6         7         8         9    ...       290       291  \
# Nurse    -0.138672 -0.063477  0.086914 -0.289062  ...  0.208984 -0.204102
# Engineer -0.086914 -0.080566 -0.231445  0.001930  ... -0.177734 -0.208008
# Woman    -0.427734  0.160156  0.229492  0.062988  ...  0.187500 -0.056152
# Man      -0.241211  0.162109  0.363281 -0.113281  ...  0.056885  0.079590
#
#                292       293       294       295       296       297  \
# Nurse    -0.289062  0.009277 -0.255859  0.250000 -0.041748  0.044434
# Engineer -0.339844  0.318359 -0.073730  0.251953 -0.326172 -0.289062
# Woman    -0.443359 -0.084961 -0.030396  0.094238 -0.154297  0.108887
# Man      -0.233398 -0.013062 -0.064453  0.056885 -0.453125 -0.056396
#
#                298       299
# Nurse     0.096680  0.269531
# Engineer  0.024414 -0.049072
# Woman    -0.084473  0.007812
# Man      -0.137695 -0.010315
#
# [4 rows x 300 columns]

# %%
pca = PCA(n_components=2)
result = pca.fit_transform(new)

# %%
plt.figure(figsize=(5,7))
plt.scatter(result[:,0],result[:,1],linewidths=6,color='red')
plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
plt.title("Word Embedding Space",size=20)
for i, word in enumerate(words):
    plt.annotate(word,xy=(result[i,0],result[i,1]))

# %% [markdown]
# As expected Man is closer to engineer and farther from nurse while Woman is closer to Nurse and farther from Engineer

# %% [markdown]
# Now looking into the word embeddings of the Leader and Follower w.r.t to the words explored just now

# %%
words = {'Man', 'Woman', 'Engineer', 'Nurse', 'Leader', 'Follower'}

dict_words_vector={}
for word in words:
    dict_words_vector[word] = model[word]
    
all_values=[]
for key,values in dict_words_vector.items():
    all_values.append(values)
    
new=pd.DataFrame(all_values)
new.index=words

pca = PCA(n_components=2)

result = pca.fit_transform(new)

plt.figure(figsize=(5,7))
plt.scatter(result[:,0],result[:,1],linewidths=6,color='red')
plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
plt.title("Word Embedding Space",size=20)
for i, word in enumerate(words):
    plt.annotate(word,xy=(result[i,0],result[i,1]))

# %% [markdown]
# Man is closer to both Follower and Leader

# %% [markdown]
# ### 2d. Plotting the word embeddings in Energy Domain

# %%
energy=['climate',
 'national',
 'market',
 'measures',
 'emissions',
 'electricity',
 'increase',
 'sector',
 'transport',
 'energy',
 'gas',
 'consumption',
 'plan',
 'development']

# %%
male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']

# %%
words = energy+male_words+female_words

# %%
dict_words_vector={}
for word in words:
    dict_words_vector[word] = model[word]
    
all_values=[]
for key,values in dict_words_vector.items():
    all_values.append(values)

# %%
new=pd.DataFrame(all_values)
new.index=words

# %%
new
# Out:
#                   0         1         2         3         4         5    \
# climate      0.178711  0.326172 -0.118652  0.120605 -0.155273 -0.210938
# national    -0.135742  0.175781  0.117188  0.078613  0.052490 -0.238281
# market      -0.156250 -0.087891 -0.229492 -0.231445 -0.007935 -0.203125
# measures    -0.142578  0.363281  0.165039  0.044922 -0.082520 -0.058350
# emissions    0.015137 -0.041748  0.503906  0.091309 -0.306641 -0.237305
# electricity  0.034180  0.019287  0.275391 -0.408203  0.102539 -0.039062
# increase    -0.105957 -0.123047 -0.158203  0.205078 -0.127930 -0.105469
# sector       0.014954 -0.251953 -0.083984 -0.041992 -0.139648 -0.185547
# transport    0.011902 -0.016357 -0.010925  0.039551 -0.112793 -0.155273
# energy      -0.103516  0.161133  0.117188 -0.253906  0.008911  0.008240
# gas         -0.161133  0.105469 -0.138672  0.010803  0.017090 -0.041504
# consumption  0.139648 -0.292969  0.065430  0.185547 -0.115234  0.220703
# plan         0.078613  0.098145  0.168945  0.083496 -0.028320 -0.105469
# development -0.157227  0.030762 -0.006958 -0.047607 -0.144531 -0.104004
# male        -0.067871  0.092285 -0.022095 -0.173828 -0.102539 -0.176758
# man          0.326172  0.130859  0.034668 -0.083008  0.089844 -0.041260
# boy          0.235352  0.165039  0.093262 -0.128906  0.015991  0.036133
# brother     -0.061279 -0.060303  0.195312 -0.137695  0.151367  0.227539
# he           0.192383  0.127930 -0.019165 -0.029297  0.031006 -0.084473
# him          0.212891  0.073730  0.053711  0.077148 -0.022949 -0.023438
# his          0.318359  0.176758  0.058594 -0.010742 -0.009399 -0.048584
# son          0.107910 -0.030029  0.033203 -0.169922  0.067871  0.146484
# father       0.047363 -0.031738  0.040771 -0.153320  0.074219  0.060547
# uncle        0.057373 -0.016357  0.164062 -0.176758  0.043457  0.131836
# grandfather  0.130859 -0.063965  0.174805 -0.070801  0.224609 -0.204102
# female      -0.116699  0.052246  0.021973 -0.156250 -0.047363 -0.283203
# woman        0.243164 -0.077148 -0.103027 -0.107422  0.118164 -0.107422
# girl         0.138672  0.003738  0.064453 -0.076172  0.024780 -0.015381
# sister      -0.236328 -0.071777  0.130859 -0.054688  0.316406  0.248047
# she          0.088379 -0.031738 -0.122559 -0.038818  0.127930 -0.137695
# her          0.146484 -0.013794 -0.019165 -0.041504  0.051025 -0.095703
# hers        -0.022461 -0.221680  0.046875  0.214844  0.032471 -0.091309
# daughter     0.029663 -0.127930 -0.003281 -0.109863  0.173828  0.136719
# mother      -0.009216 -0.211914  0.021606 -0.025879  0.131836  0.113281
# aunt         0.078125 -0.151367  0.205078 -0.000378  0.108398  0.116699
# grandmother  0.145508 -0.203125  0.114746  0.015869  0.289062  0.042480
#
#                   6         7         8         9    ...       290       291  \
# climate      0.004608 -0.038818 -0.006775  0.167969  ... -0.394531  0.154297
# national     0.092773 -0.083984  0.061523 -0.062500  ...  0.034180 -0.039551
# market      -0.023682 -0.092285  0.223633  0.056396  ...  0.038330  0.080566
# measures     0.037109  0.066895  0.056152 -0.191406  ... -0.404297 -0.048828
# emissions    0.088379 -0.029419  0.271484  0.429688  ... -0.141602  0.123535
# electricity  0.096191 -0.402344  0.181641  0.142578  ... -0.233398 -0.136719
# increase    -0.105469 -0.298828  0.167969  0.250000  ...  0.000441  0.096680
# sector      -0.169922 -0.281250  0.062988 -0.208984  ... -0.167969 -0.153320
# transport   -0.160156 -0.345703  0.132812 -0.061035  ... -0.330078 -0.166016
# energy       0.103027 -0.400391  0.094238  0.030640  ... -0.237305 -0.132812
# gas         -0.145508 -0.341797 -0.028564  0.184570  ... -0.111328 -0.218750
# consumption  0.188477 -0.312500  0.298828  0.208008  ... -0.007294 -0.232422
# plan         0.055908  0.043701 -0.014465 -0.248047  ... -0.302734  0.042480
# development  0.136719 -0.279297 -0.104980  0.095215  ... -0.253906  0.076660
# male        -0.044434  0.075684  0.079102  0.023682  ... -0.009216  0.253906
# man         -0.198242  0.006897  0.143555  0.001945  ...  0.155273 -0.031250
# boy         -0.116699 -0.073242  0.138672  0.011536  ...  0.019043 -0.010315
# brother     -0.059814 -0.150391  0.178711  0.015320  ... -0.213867 -0.018555
# he          -0.099609 -0.053467  0.165039 -0.033691  ... -0.061768 -0.043457
# him         -0.203125 -0.123535  0.004303 -0.096680  ... -0.029175  0.298828
# his         -0.072266 -0.172852 -0.024170 -0.169922  ... -0.098145 -0.006134
# son         -0.037109 -0.204102  0.157227 -0.122559  ... -0.185547 -0.150391
# father      -0.025269 -0.208984  0.127930  0.004883  ... -0.224609 -0.041016
# uncle       -0.134766 -0.188477  0.094727  0.071289  ... -0.255859  0.014648
# grandfather -0.043945 -0.076172  0.191406  0.082520  ... -0.203125 -0.006622
# female      -0.054443  0.031982  0.073242  0.064941  ...  0.039062  0.137695
# woman       -0.114258  0.025635  0.111816  0.048584  ...  0.103516 -0.066406
# girl        -0.111816 -0.101562  0.046143  0.091797  ...  0.020264  0.024292
# sister      -0.093750 -0.178711  0.133789  0.110840  ... -0.177734 -0.095703
# she         -0.062988 -0.051025 -0.082031  0.010498  ... -0.058594 -0.084961
# her         -0.041992 -0.151367 -0.263672 -0.118164  ... -0.096680  0.011719
# hers         0.156250  0.017700  0.002197  0.053467  ... -0.081055  0.072754
# daughter     0.008057 -0.300781  0.096191 -0.083496  ... -0.182617 -0.112305
# mother       0.025513 -0.193359  0.007599  0.078613  ... -0.166992 -0.083496
# aunt        -0.177734 -0.173828 -0.034912  0.114746  ... -0.257812 -0.044678
# grandmother -0.045410 -0.089844  0.047852  0.141602  ... -0.124023 -0.073242
#
#                   292       293       294       295       296       297  \
# climate      0.173828  0.201172  0.211914  0.135742 -0.003601  0.417969
# national     0.034424 -0.075195  0.006775 -0.110840  0.069336 -0.068359
# market      -0.065918 -0.087402  0.059082  0.231445 -0.050781  0.141602
# measures     0.259766 -0.086914 -0.081055  0.160156  0.064453  0.141602
# emissions    0.324219 -0.100098 -0.177734  0.223633  0.114258  0.316406
# electricity -0.308594  0.073242 -0.108398 -0.003387 -0.292969 -0.014771
# increase    -0.118164 -0.085938 -0.271484 -0.089844 -0.245117  0.005371
# sector      -0.212891 -0.055908 -0.047119 -0.212891 -0.156250 -0.106934
# transport    0.021362  0.080566  0.022217 -0.007050 -0.155273 -0.024780
# energy      -0.015198 -0.093262 -0.079102 -0.065430  0.186523  0.045898
# gas         -0.203125  0.140625 -0.041992  0.026611  0.120605  0.255859
# consumption  0.271484  0.041992 -0.134766 -0.075684  0.059326 -0.228516
# plan         0.055420 -0.189453 -0.151367  0.055664 -0.048340 -0.285156
# development -0.089355  0.053467  0.048096  0.053955 -0.035156 -0.146484
# male        -0.082520 -0.120605 -0.165039  0.095215  0.018799  0.044189
# man         -0.202148 -0.129883 -0.100586 -0.063965 -0.083496 -0.302734
# boy         -0.115234 -0.291016 -0.059570 -0.053711 -0.074219 -0.265625
# brother     -0.257812 -0.207031  0.081543 -0.087402 -0.231445 -0.396484
# he          -0.113770 -0.008728 -0.127930  0.107422  0.004120 -0.172852
# him         -0.292969 -0.121094 -0.199219  0.038574  0.034424 -0.160156
# his         -0.114746 -0.121582 -0.232422 -0.110352  0.045410 -0.098145
# son         -0.184570 -0.218750  0.077148 -0.097168 -0.191406 -0.219727
# father      -0.233398 -0.249023  0.051758 -0.040039 -0.261719 -0.244141
# uncle       -0.263672 -0.235352  0.018555 -0.008850 -0.322266 -0.335938
# grandfather -0.423828 -0.244141  0.032471  0.050781 -0.341797 -0.175781
# female      -0.211914 -0.248047 -0.273438  0.027710  0.177734  0.120117
# woman       -0.267578 -0.247070 -0.072754  0.107910  0.118652 -0.083008
# girl        -0.223633 -0.289062 -0.112305  0.068359  0.066895 -0.086914
# sister      -0.296875 -0.204102 -0.001595  0.046143 -0.031494 -0.085938
# she         -0.214844 -0.120117 -0.178711  0.072266  0.212891  0.023438
# her         -0.257812 -0.229492 -0.273438 -0.058594  0.205078  0.041992
# hers        -0.267578 -0.136719  0.023560 -0.090820  0.316406  0.024658
# daughter    -0.269531 -0.283203 -0.008850 -0.081543 -0.012939 -0.107910
# mother      -0.181641 -0.218750 -0.059082  0.039307 -0.085938 -0.087402
# aunt        -0.371094 -0.184570 -0.096191  0.120117 -0.122070 -0.182617
# grandmother -0.410156 -0.234375 -0.039307  0.090332 -0.079590 -0.196289
#
#                   298       299
# climate      0.314453  0.065430
# national     0.032471 -0.009338
# market       0.047363 -0.013550
# measures     0.045898 -0.107422
# emissions    0.223633 -0.100586
# electricity  0.275391  0.044678
# increase    -0.121582 -0.075684
# sector      -0.062500 -0.073242
# transport    0.055420  0.012817
# energy       0.153320  0.240234
# gas          0.202148 -0.019287
# consumption  0.007935  0.077637
# plan        -0.045898 -0.115723
# development  0.012573  0.110352
# male        -0.012512  0.232422
# man         -0.080078  0.020996
# boy         -0.103027  0.135742
# brother     -0.090332  0.210938
# he           0.123047 -0.160156
# him         -0.058105 -0.015442
# his          0.052490 -0.002335
# son         -0.048828  0.175781
# father       0.029297  0.088379
# uncle        0.040771  0.132812
# grandfather  0.153320 -0.026489
# female      -0.000542  0.133789
# woman        0.065430 -0.029419
# girl        -0.008972  0.037598
# sister       0.147461  0.053467
# she          0.248047 -0.117676
# her          0.163086  0.020264
# hers         0.064453 -0.010437
# daughter     0.043945  0.078613
# mother       0.145508 -0.007721
# aunt         0.263672 -0.136719
# grandmother  0.133789 -0.081055
#
# [36 rows x 300 columns]

# %%
pca = PCA(n_components=2)
result = pca.fit_transform(new)

# %%
def map_word(x):
    male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
    female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']
    energy=['climate', 'national','market','measures','emissions', 'electricity','increase','sector','transport', 'energy','gas','consumption','plan','development']
    if x in male_words:
        return 'male_word'
    if x in female_words:
        return 'female_word'
    if x in energy:
        return 'energy'

# %%
res_trans = result.T
df_result = pd.DataFrame({'PC1': res_trans[0], 'PC2': res_trans[1], 'word':words})
df_result['type_word'] = df_result['word'].apply(map_word)

# %% [markdown]
# #### 2D Plot of Overall word embeddings

# %%
plt.figure(figsize=(20,20))
plt.scatter(result[:,0],result[:,1],linewidths=3,color='black')
plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
plt.title("Word Embedding Space",size=20)
for i, word in enumerate(words):
    if word in male_words: 
        color = 'blue' 
        #plt.scatter(result[i,0],result[i,1],linewidths=5,color=color, label = 'male_word')
        plt.annotate(word,xy=(result[i,0],result[i,1]), size=22, color = color)
    if word in female_words: 
        color = 'red'
        #plt.scatter(result[i,0],result[i,1],linewidths=5,color=color, label = 'female_word')
        plt.annotate(word,xy=(result[i,0],result[i,1]), size=22, color = color)
    if word in energy:
        color = 'green'
        #plt.scatter(result[i,0],result[i,1],linewidths=5,color=color, label = 'female_word')
        plt.annotate(word,xy=(result[i,0],result[i,1]), size=22, color = color, label='energy_word')

# %% [markdown]
# #### Interactive plot of overall word embeddings

# %%
import plotly.express as px

fig = px.scatter(df_result,x='PC1',y='PC2',text='word',color='type_word', width=1000, height=600,color_discrete_map={"energy": 'green',
                                                             "male_word":'blue',
                                                             "female_word": 'red'
                                                            })

fig.update_layout(
    title = "Word Embedding Space",
    font={'size':15}
    
)

fig.show()
# Out:
# <div>                            <div id="3db4efd2-9c8e-4a86-a790-e6ae4260af43" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3db4efd2-9c8e-4a86-a790-e6ae4260af43")) {                    Plotly.newPlot(                        "3db4efd2-9c8e-4a86-a790-e6ae4260af43",                        [{"hovertemplate":"type_word=energy<br>PC1=%{x}<br>PC2=%{y}<br>word=%{text}<extra></extra>","legendgroup":"energy","marker":{"color":"green","symbol":"circle"},"mode":"markers+text","name":"energy","orientation":"v","showlegend":true,"text":["energy","electricity","climate","measures","national","consumption","plan","transport","sector","emissions","production","system","renewable"],"x":[1.301650881767273,1.174730658531189,1.2125120162963867,0.9599950909614563,0.5367422103881836,1.3290281295776367,0.6937012076377869,1.1276072263717651,1.1513420343399048,1.8100934028625488,1.0056565999984741,0.7314632534980774,1.5841410160064697],"xaxis":"x","y":[0.8944371938705444,1.224566102027893,0.21017391979694366,-0.2716856002807617,-0.5090901255607605,0.4899417757987976,-0.4054890275001526,-0.012607765384018421,-0.2114829421043396,2.097916603088379,-0.0803808644413948,-0.4554122984409332,1.7201805114746094],"yaxis":"y","type":"scatter"},{"hovertemplate":"type_word=male_word<br>PC1=%{x}<br>PC2=%{y}<br>word=%{text}<extra></extra>","legendgroup":"male_word","marker":{"color":"blue","symbol":"circle"},"mode":"markers+text","name":"male_word","orientation":"v","showlegend":true,"text":["male","man","boy","brother","he","him","his","son","father","uncle","grandfather"],"x":[-0.07966147363185883,-0.6578071117401123,-1.3278616666793823,-1.4011904001235962,-0.09624383598566055,-0.3292602598667145,-0.1448042243719101,-1.5430707931518555,-1.4155590534210205,-1.4774574041366577,-1.382434368133545],"xaxis":"x","y":[-1.3026788234710693,-0.5214259028434753,-0.26665034890174866,0.6481189131736755,-0.39198029041290283,-0.4260597825050354,-0.4905237853527069,0.5111356377601624,0.5464702844619751,0.7696903944015503,0.9331127405166626],"yaxis":"y","type":"scatter"},{"hovertemplate":"type_word=female_word<br>PC1=%{x}<br>PC2=%{y}<br>word=%{text}<extra></extra>","legendgroup":"female_word","marker":{"color":"red","symbol":"circle"},"mode":"markers+text","name":"female_word","orientation":"v","showlegend":true,"text":["female","woman","girl","sister","she","her","hers","daughter","mother","aunt","grandmother"],"x":[0.003989897668361664,-0.9965949654579163,-1.342246413230896,-1.3519431352615356,-0.4851236343383789,-0.6004946231842041,-0.49406641721725464,-1.6732794046401978,-1.550815463066101,-1.7430574893951416,-1.776935338973999],"xaxis":"x","y":[-1.34893798828125,-0.6965337991714478,-0.4449198544025421,0.529876708984375,-0.5749332308769226,-0.6261577010154724,-0.38541868329048157,0.4346037209033966,0.4000155031681061,0.7910351157188416,0.7192983627319336],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"], ...

# %% [markdown]
# ### 2e. Word Embedding plot for all the countries

# %%
os.chdir(output_data_location)
all_necps_csv_filepath = []
for file in glob.glob("*main_en_0.csv"):
    all_necps_csv_filepath.append(file)

male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']
for necp in all_necps_csv_filepath:
    print(necp)
    all_values=[]
    words_not_found = []
    dict_words_vector={}
    labels = []
    df1 = pd.read_csv(necp)
    df1 = df1.head(25)
    individual_word_set = df1['word'].to_list()
    words = individual_word_set+ male_words + female_words
    for word in words:
        try:
            dict_words_vector[word] = model[word]
            labels.append(word)
        except:
            words_not_found.append(word)
            print(f'The vector for {word} doesnt esixt')
            pass
        
    for key,values in dict_words_vector.items():
        all_values.append(values)
    
    words = [word for word in words if word not in words_not_found]
    new=pd.DataFrame(all_values)
    new.index=words
    pca = PCA(n_components=2)
    result = pca.fit_transform(new)
    
    plt.figure(figsize=(13,7))
    plt.scatter(result[:,0],result[:,1],linewidths=3,color='blue')
    plt.xlabel("PC1",size=15)
    plt.ylabel("PC2",size=15)
    plt.title("Word Embedding Space",size=20)
    for i, word in enumerate(words):
        plt.annotate(word,xy=(result[i,0],result[i,1]))
# Out:
# dk_final_necp_main_en_0.csv
# hu_final_necp_main_en_0.csv
# lt_final_necp_main_en_0.csv
# The vector for lithuania doesnt esixt
# hr_final_necp_main_en_0.csv
# es_final_necp_main_en_0.csv
# The vector for inecp doesnt esixt
# cs_final_necp_main_en_0.csv
# pl_final_necp_main_en_0.csv
# The vector for ecp doesnt esixt
# el_final_necp_main_en_0.csv
# fi_final_necp_main_en_0.csv
# ie_final_necp_main_en_0.csv
# be_final_necp_main_en_0.csv
# The vector for flemish doesnt esixt
# at_final_necp_main_en_0.csv
# ee_final_necp_main_en_0.csv
# The vector for estonia doesnt esixt
# The vector for estonian doesnt esixt
# de_final_necp_main_en_0.csv
# The vector for programme doesnt esixt
# nl_final_necp_main_en_0.csv
# cy_final_necp_main_en_0.csv
# se_final_necp_main_en_0.csv
# lv_final_necp_main_en_0.csv
# The vector for latvia doesnt esixt
# sk_final_necp_main_en_0.csv
# The vector for slovak doesnt esixt
# si_final_necp_main_en_0.csv
# The vector for slovenia doesnt esixt
# The vector for nepn doesnt esixt
# pt_final_necp_main_en_0.csv
# The vector for necp doesnt esixt
# it_final_necp_main_en_0.csv
# ro_final_necp_main_en_0.csv
# The vector for tegrated doesnt esixt
# mt_final_necp_main_en_0.csv
# lu_final_necp_main_en_0.csv
# The vector for luxembourg doesnt esixt
# fr_final_necp_main_en_0.csv
# bg_final_necp_main_en_0.csv
# The vector for bulgaria doesnt esixt

# %% [markdown]
# ## Part 3. Bias Evaluation

# %% [markdown]
# #### Checking the bias with the an initial list :-

# %%
male_words = ['he', 'man', 'male', 'father']
female_words = ['she', 'woman', 'female', 'mother']

# %%
energy=['measures',
 'transport',
 'sector',
 'emissions',
 'electricity',
 'market',
 'increase',
 'national',
 'development',
 'climate',
 'energy',
 'gas',
 'plan',
 'consumption']

# %%
google_news = api.load('word2vec-google-news-300')

# %%
model1 = WordEmbeddingModel(google_news, 'google_news')

# %%
target_sets = []
target_sets.append(male_words)
target_sets.append(female_words)

# %%
target_sets
# Out:
# [['he', 'man', 'male', 'father'], ['she', 'woman', 'female', 'mother']]

# %%
attribute_sets = []
#word = word_occuring_in_all_documents['Word'].to_list()
attribute_sets.append(energy)

# %%
target_sets_names = ['Male Terms', 'Female Terms']
attribute_sets_name = ['Energy']
# create the query
query = Query(target_sets, attribute_sets, target_sets_names,
              attribute_sets_name)

# %%
RND().run_query(query, model1)
# Out:
# {'query_name': 'Male Terms and Female Terms wrt Energy',
#  'result': -0.18204990455082484,
#  'rnd': -0.18204990455082484,
#  'distances_by_word': {'plan': -0.2694645,
#   'national': -0.23181629,
#   'development': -0.22860193,
#   'market': -0.2007482,
#   'energy': -0.19927883,
#   'sector': -0.19634795,
#   'measures': -0.19348407,
#   'emissions': -0.16940546,
#   'increase': -0.16109705,
#   'gas': -0.15570903,
#   'transport': -0.14803576,
#   'consumption': -0.14657235,
#   'climate': -0.12866068,
#   'electricity': -0.11947656}}

# %% [markdown]
# Interpretation: The more negative the score is the more is the association with the Male Category.

# %% [markdown]
# #### This clearly indicates that the model is biased towards the male

# %% [markdown]
# #### Expanding the list to Chaloner's list

# %%
expanded_male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
expanded_female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']

expanded_target_sets = []
expanded_target_sets.append(expanded_male_words)
expanded_target_sets.append(expanded_female_words)

target_sets_names = ['Expanded Male Terms', 'Expanded Female Terms']
attribute_sets_name = ['Energy']
# create the query
query = Query(expanded_target_sets, attribute_sets, target_sets_names,
              attribute_sets_name)

RND().run_query(query, model1)
# Out:
# {'query_name': 'Expanded Male Terms and Expanded Female Terms wrt Energy',
#  'result': -0.14185542719704763,
#  'rnd': -0.14185542719704763,
#  'distances_by_word': {'plan': -0.2170732,
#   'national': -0.20355964,
#   'energy': -0.17686343,
#   'sector': -0.17655921,
#   'development': -0.1745894,
#   'market': -0.15568328,
#   'measures': -0.14062619,
#   'increase': -0.13483524,
#   'transport': -0.12860942,
#   'gas': -0.1146698,
#   'electricity': -0.096247435,
#   'climate': -0.0930686,
#   'emissions': -0.08683252,
#   'consumption': -0.08675861}}

# %% [markdown]
# #### With expanded list it clearly indicates that the model is biased towards the male

# %% [markdown]
# #### Now trying with all the individual country files

# %%
os.chdir(output_data_location)
all_necps_csv_filepath = []
for file in glob.glob("*main_en_0.csv"):
    all_necps_csv_filepath.append(file)

# %%
expanded_male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
expanded_female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']
expanded_target_sets = []
target_sets_names = ['Expanded Male Terms', 'Expanded Female Terms']
expanded_target_sets.append(expanded_male_words)
expanded_target_sets.append(expanded_female_words)

for necp in all_necps_csv_filepath:
    attribute_sets = []
    df1 = pd.read_csv(necp)
    attribute_sets.append(df1['word'].to_list())
    query = Query(expanded_target_sets, attribute_sets, target_sets_names, attribute_sets_name)
    data = RND().run_query(query, model1)['distances_by_word']
    df2 = pd.DataFrame.from_dict(data, orient='index', columns=['rnd_score']).reset_index().rename(columns = {'index': 'word'})
    df3 = (df1.merge(df2, on='word', how='left'))
    df3.to_csv(necp + ' merged_scores'+ '.csv', index=False)

# %%
all_scoress_filepath = []
for file in glob.glob('*merged_scores.csv'):
    all_scoress_filepath.append(file)

# %%
scores_across_countries = {}
for file in all_scoress_filepath:
    df1= pd.read_csv(file)
    df1 = df1.copy()
    df1['weight*rnd_score'] = df1['weight']*df1['rnd_score']
    score = (df1['weight*rnd_score'].sum())/(df1.weight.sum())
    df1['final_score'] = (df1['weight*rnd_score'].sum())/(df1.weight.sum())
    scores_across_countries[os.path.splitext(file)[0].split()[0]] = score

# %%
scores = pd.DataFrame.from_dict(scores_across_countries, orient='index', columns=['final_score']).reset_index().rename(columns={'index':'file'})

# %%
scores.sort_values('final_score')
# Out:
#                            file  final_score
# 21  pt_final_necp_main_en_0.csv    -0.150049
# 13  it_final_necp_main_en_0.csv    -0.147303
# 25  el_final_necp_main_en_0.csv    -0.143879
# 6   es_final_necp_main_en_0.csv    -0.143653
# 19  ro_final_necp_main_en_0.csv    -0.143153
# 4   fr_final_necp_main_en_0.csv    -0.143002
# 23  at_final_necp_main_en_0.csv    -0.142498
# 18  fi_final_necp_main_en_0.csv    -0.141270
# 0   hr_final_necp_main_en_0.csv    -0.140733
# 9   cs_final_necp_main_en_0.csv    -0.140713
# 14  dk_final_necp_main_en_0.csv    -0.140686
# 3   mt_final_necp_main_en_0.csv    -0.140585
# 8   ie_final_necp_main_en_0.csv    -0.139797
# 24  nl_final_necp_main_en_0.csv    -0.139417
# 12  pl_final_necp_main_en_0.csv    -0.139115
# 17  be_final_necp_main_en_0.csv    -0.139025
# 22  sk_final_necp_main_en_0.csv    -0.138184
# 5   cy_final_necp_main_en_0.csv    -0.137927
# 26  se_final_necp_main_en_0.csv    -0.136422
# 11  hu_final_necp_main_en_0.csv    -0.135672
# 10  de_final_necp_main_en_0.csv    -0.134791
# 1   lu_final_necp_main_en_0.csv    -0.134778
# 7   lv_final_necp_main_en_0.csv    -0.134136
# 15  bg_final_necp_main_en_0.csv    -0.133741
# 20  lt_final_necp_main_en_0.csv    -0.132980
# 2   ee_final_necp_main_en_0.csv    -0.132674
# 16  si_final_necp_main_en_0.csv    -0.127197

# %%
scores.sort_values('final_score').to_csv('final_scores_necp.csv', index=False)

# %% [markdown]
# This indicates that Portugal is the most biased and Slovenia is the least biased

# %% [markdown]
# Looking at the word embedding chart for the most biased country - Portugal

# %% [markdown]
# #### 2D Plot of Portugal Word embeddings

# %%
all_values=[]
words_not_found = []
dict_words_vector={}
labels = []
df1 = pd.read_csv('pt_final_necp_main_en_0.csv')
df1 = df1.head(25)
individual_word_set = df1['word'].to_list()
words = individual_word_set+ expanded_male_words + expanded_female_words
for word in words:
    try:
        dict_words_vector[word] = model[word]
        labels.append(word)
    except:
        words_not_found.append(word)
        print(f'The vector for {word} doesnt esixt')
        pass
        
for key,values in dict_words_vector.items():
    all_values.append(values)
    
words = [word for word in words if word not in words_not_found]
new=pd.DataFrame(all_values)
new.index=words
pca = PCA(n_components=2)
result = pca.fit_transform(new)

res_trans = result.T
df_result = pd.DataFrame({'PC1': res_trans[0], 'PC2': res_trans[1], 'word':words})
df_result['type_word'] = df_result['word'].apply(map_word)
    
plt.figure(figsize=(25,30))
plt.scatter(result[:,0],result[:,1],linewidths=4,color='black')
plt.xlabel("PC1",size=20)
plt.ylabel("PC2",size=20)
plt.title("Word Embedding Space Portugal",size=20)
for i, word in enumerate(words):
    if word in expanded_male_words: 
        color = 'blue' 
        #plt.scatter(result[i,0],result[i,1],linewidths=5,color=color, label = 'male_word')
        plt.annotate(word,xy=(result[i,0],result[i,1]), size=22, color = color)
    if word in expanded_female_words: 
        color = 'red'
        #plt.scatter(result[i,0],result[i,1],linewidths=5,color=color, label = 'female_word')
        plt.annotate(word,xy=(result[i,0],result[i,1]), size=22, color = color)
    if word in individual_word_set:
        color = 'green'
        #plt.scatter(result[i,0],result[i,1],linewidths=5,color=color, label = 'female_word')
        plt.annotate(word,xy=(result[i,0],result[i,1]), size=22, color = color)
# Out:
# The vector for necp doesnt esixt

# %%
def map_word_file(x, file_name='pt_final_necp_main_en_0.csv'):
    expanded_male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
    expanded_female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']
    df1 = pd.read_csv(file_name)
    df1 = df1.head(25)
    individual_word_set = df1['word'].to_list()
    if x in expanded_male_words:
        return 'male_word'
    if x in female_words:
        return 'female_word'
    if x in individual_word_set:
        return 'energy'

# %% [markdown]
# #### Interctive Plot of Portugal

# %%
all_values=[]
words_not_found = []
dict_words_vector={}
labels = []

for word in words:
    try:
        dict_words_vector[word] = model[word]
        labels.append(word)
    except:
        words_not_found.append(word)
        print(f'The vector for {word} doesnt esixt')
        pass
        
for key,values in dict_words_vector.items():
    all_values.append(values)
    
words = [word for word in words if word not in words_not_found]
new=pd.DataFrame(all_values)
new.index=words
pca = PCA(n_components=2)
result = pca.fit_transform(new)

res_trans = result.T
df_result = pd.DataFrame({'PC1': res_trans[0], 'PC2': res_trans[1], 'word':words})
df_result['type_word'] = df_result['word'].apply(map_word_file)

    
    
import plotly.express as px

fig = px.scatter(df_result,x='PC1',y='PC2',text='word',color='type_word',
                 width=1000, height=600, color_discrete_map={"energy": 'green',
                                                             "male_word":'blue',
                                                             "female_word": 'red'
                                                            })


fig.update_layout(
    title = "Word Embedding Space",
    font={'size':15}
    
)

fig.show()
# Out:
# <div>                            <div id="62539ff8-d91d-4ac8-a64f-453095231410" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62539ff8-d91d-4ac8-a64f-453095231410")) {                    Plotly.newPlot(                        "62539ff8-d91d-4ac8-a64f-453095231410",                        [{"hovertemplate":"type_word=energy<br>PC1=%{x}<br>PC2=%{y}<br>word=%{text}<extra></extra>","legendgroup":"energy","marker":{"color":"green","symbol":"circle"},"mode":"markers+text","name":"energy","orientation":"v","showlegend":true,"text":["energy","electricity","climate","measures","national","consumption","plan","transport","sector","emissions","production","system","renewable"],"x":[1.301650881767273,1.174730658531189,1.2125120162963867,0.9599950909614563,0.5367422103881836,1.3290281295776367,0.6937012076377869,1.1276072263717651,1.1513420343399048,1.8100934028625488,1.0056565999984741,0.7314632534980774,1.5841410160064697],"xaxis":"x","y":[0.8944371938705444,1.224566102027893,0.21017391979694366,-0.2716856002807617,-0.5090901255607605,0.4899417757987976,-0.4054890275001526,-0.012607765384018421,-0.2114829421043396,2.097916603088379,-0.0803808644413948,-0.4554122984409332,1.7201805114746094],"yaxis":"y","type":"scatter"},{"hovertemplate":"type_word=male_word<br>PC1=%{x}<br>PC2=%{y}<br>word=%{text}<extra></extra>","legendgroup":"male_word","marker":{"color":"blue","symbol":"circle"},"mode":"markers+text","name":"male_word","orientation":"v","showlegend":true,"text":["male","man","boy","brother","he","him","his","son","father","uncle","grandfather"],"x":[-0.07966147363185883,-0.6578071117401123,-1.3278616666793823,-1.4011904001235962,-0.09624383598566055,-0.3292602598667145,-0.1448042243719101,-1.5430707931518555,-1.4155590534210205,-1.4774574041366577,-1.382434368133545],"xaxis":"x","y":[-1.3026788234710693,-0.5214259028434753,-0.26665034890174866,0.6481189131736755,-0.39198029041290283,-0.4260597825050354,-0.4905237853527069,0.5111356377601624,0.5464702844619751,0.7696903944015503,0.9331127405166626],"yaxis":"y","type":"scatter"},{"hovertemplate":"type_word=female_word<br>PC1=%{x}<br>PC2=%{y}<br>word=%{text}<extra></extra>","legendgroup":"female_word","marker":{"color":"red","symbol":"circle"},"mode":"markers+text","name":"female_word","orientation":"v","showlegend":true,"text":["female","woman","girl","sister","she","her","hers","daughter","mother","aunt","grandmother"],"x":[0.003989897668361664,-0.9965949654579163,-1.342246413230896,-1.3519431352615356,-0.4851236343383789,-0.6004946231842041,-0.49406641721725464,-1.6732794046401978,-1.550815463066101,-1.7430574893951416,-1.776935338973999],"xaxis":"x","y":[-1.34893798828125,-0.6965337991714478,-0.4449198544025421,0.529876708984375,-0.5749332308769226,-0.6261577010154724,-0.38541868329048157,0.4346037209033966,0.4000155031681061,0.7910351157188416,0.7192983627319336],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"], ...

# %% [markdown]
# Looking at the word embedding chart for the most biased country - Slovenia

# %% [markdown]
# #### 2D Plot of word embeddings of Slovenia

# %%
all_values=[]
words_not_found = []
dict_words_vector={}
labels = []
df1 = pd.read_csv('si_final_necp_main_en_0.csv')
df1 = df1.head(25)
individual_word_set = df1['word'].to_list()
words = individual_word_set+ expanded_male_words + expanded_female_words
for word in words:
    try:
        dict_words_vector[word] = model[word]
        labels.append(word)
    except:
        words_not_found.append(word)
        print(f'The vector for {word} doesnt esixt')
        pass
        
for key,values in dict_words_vector.items():
    all_values.append(values)
    
words = [word for word in words if word not in words_not_found]
new=pd.DataFrame(all_values)
new.index=words
pca = PCA(n_components=2)
result = pca.fit_transform(new)

plt.figure(figsize=(20,35))
plt.scatter(result[:,0],result[:,1],linewidths=4,color='black')
plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
plt.title("Word Embedding Space slovenia",size=20)
for i, word in enumerate(words):
    if word in expanded_male_words: 
        color = 'blue' 
        #plt.scatter(result[i,0],result[i,1],linewidths=5,color=color, label = 'male_word')
        plt.annotate(word,xy=(result[i,0],result[i,1]), size=22, color = color)
    if word in expanded_female_words: 
        color = 'red'
        #plt.scatter(result[i,0],result[i,1],linewidths=5,color=color, label = 'female_word')
        plt.annotate(word,xy=(result[i,0],result[i,1]), size=22, color = color)
    if word in individual_word_set:
        color = 'green'
        #plt.scatter(result[i,0],result[i,1],linewidths=5,color=color, label = 'female_word')
        plt.annotate(word,xy=(result[i,0],result[i,1]), size=22, color = color)
# Out:
# The vector for slovenia doesnt esixt
# The vector for nepn doesnt esixt

# %% [markdown]
# #### Interactive plot of word embeddings of Slovenia

# %%
all_values=[]
words_not_found = []
dict_words_vector={}
labels = []
df1 = pd.read_csv('si_final_necp_main_en_0.csv')
df1 = df1.head(25)
individual_word_set = df1['word'].to_list()
words = individual_word_set+ expanded_male_words + expanded_female_words
for word in words:
    try:
        dict_words_vector[word] = model[word]
        labels.append(word)
    except:
        words_not_found.append(word)
        print(f'The vector for {word} doesnt esixt')
        pass
        
for key,values in dict_words_vector.items():
    all_values.append(values)
    
words = [word for word in words if word not in words_not_found]
new=pd.DataFrame(all_values)
new.index=words
pca = PCA(n_components=2)
result = pca.fit_transform(new)

res_trans = result.T
df_result = pd.DataFrame({'PC1': res_trans[0], 'PC2': res_trans[1], 'word':words})
df_result['type_word'] = df_result['word'].apply(map_word_file,'si_final_necp_main_en_0.csv')

    
    
import plotly.express as px

fig = px.scatter(df_result,x='PC1',y='PC2',text='word',color='type_word', 
                 width=1000, height=600,color_discrete_map={"energy": 'green',
                                                             "male_word":'blue',
                                                             "female_word": 'red'
                                                            })

fig.update_layout(
    title = "Word Embedding Space",
    font={'size':15}
    
)

fig.show()
# Out:
# The vector for slovenia doesnt esixt
# The vector for nepn doesnt esixt
# <div>                            <div id="f871012e-5119-45ea-8783-b10a390f94c5" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f871012e-5119-45ea-8783-b10a390f94c5")) {                    Plotly.newPlot(                        "f871012e-5119-45ea-8783-b10a390f94c5",                        [{"hovertemplate":"type_word=energy<br>PC1=%{x}<br>PC2=%{y}<br>word=%{text}<extra></extra>","legendgroup":"energy","marker":{"color":"green","symbol":"circle"},"mode":"markers+text","name":"energy","orientation":"v","showlegend":true,"text":["energy","electricity","climate","measures","national","consumption","plan","transport","sector","emissions","production","system","renewable"],"x":[1.301650881767273,1.174730658531189,1.2125120162963867,0.9599950909614563,0.5367422103881836,1.3290281295776367,0.6937012076377869,1.1276072263717651,1.1513420343399048,1.8100934028625488,1.0056565999984741,0.7314632534980774,1.5841410160064697],"xaxis":"x","y":[0.8944371938705444,1.224566102027893,0.21017391979694366,-0.2716856002807617,-0.5090901255607605,0.4899417757987976,-0.4054890275001526,-0.012607765384018421,-0.2114829421043396,2.097916603088379,-0.0803808644413948,-0.4554122984409332,1.7201805114746094],"yaxis":"y","type":"scatter"},{"hovertemplate":"type_word=male_word<br>PC1=%{x}<br>PC2=%{y}<br>word=%{text}<extra></extra>","legendgroup":"male_word","marker":{"color":"blue","symbol":"circle"},"mode":"markers+text","name":"male_word","orientation":"v","showlegend":true,"text":["male","man","boy","brother","he","him","his","son","father","uncle","grandfather"],"x":[-0.07966147363185883,-0.6578071117401123,-1.3278616666793823,-1.4011904001235962,-0.09624383598566055,-0.3292602598667145,-0.1448042243719101,-1.5430707931518555,-1.4155590534210205,-1.4774574041366577,-1.382434368133545],"xaxis":"x","y":[-1.3026788234710693,-0.5214259028434753,-0.26665034890174866,0.6481189131736755,-0.39198029041290283,-0.4260597825050354,-0.4905237853527069,0.5111356377601624,0.5464702844619751,0.7696903944015503,0.9331127405166626],"yaxis":"y","type":"scatter"},{"hovertemplate":"type_word=female_word<br>PC1=%{x}<br>PC2=%{y}<br>word=%{text}<extra></extra>","legendgroup":"female_word","marker":{"color":"red","symbol":"circle"},"mode":"markers+text","name":"female_word","orientation":"v","showlegend":true,"text":["female","woman","girl","sister","she","her","hers","daughter","mother","aunt","grandmother"],"x":[0.003989897668361664,-0.9965949654579163,-1.342246413230896,-1.3519431352615356,-0.4851236343383789,-0.6004946231842041,-0.49406641721725464,-1.6732794046401978,-1.550815463066101,-1.7430574893951416,-1.776935338973999],"xaxis":"x","y":[-1.34893798828125,-0.6965337991714478,-0.4449198544025421,0.529876708984375,-0.5749332308769226,-0.6261577010154724,-0.38541868329048157,0.4346037209033966,0.4000155031681061,0.7910351157188416,0.7192983627319336],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"], ...

# %% [markdown]
# #### WEAT  Query

# %% [markdown]
# The idea is that the more positive the metric value, the more target T 1 will be
# related to attribute A 1 and target T 2 to attribute A 2 . On the other hand, the more
# negative the value, the more target T 1 will be related to attribute A 2 and target T 2
# to attribute A 1 . The score that represents the absence of social bias is zero.

# %% [markdown]
# #### Arts vs Energy

# %%
energy = word_occuring_in_all_documents['Word'].to_list()
arts = ['poetry','dance','literature', 'singing', 'painting', 'cooking']
expanded_male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
expanded_female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']

expanded_target_sets = []
expanded_target_sets.append(expanded_male_words)
expanded_target_sets.append(expanded_female_words)

target_sets_names = ['Expanded Male Terms', 'Expanded Female Terms']
attribute_sets = [arts, energy]
attribute_sets_name = ['Arts','Energy']
# create the query
query = Query(expanded_target_sets, attribute_sets, target_sets_names,
              attribute_sets_name)

WEAT().run_query(query, model1, calculate_p_value=True, p_value_iterations=5000)
# Out:
# {'query_name': 'Expanded Male Terms and Expanded Female Terms wrt Arts and Energy',
#  'result': -0.733634944043366,
#  'weat': -0.733634944043366,
#  'effect_size': -1.5027829370857655,
#  'p_value': 0.9996000799840032}

# %% [markdown]
# #### Arts Vs Science

# %%
arts = ['poetry','dance','literature', 'singing', 'painting', 'cooking']
science = ['math', 'physics', 'chemistry', 'science', 'space', 'engineering']
expanded_male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
expanded_female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']

expanded_target_sets = []
expanded_target_sets.append(expanded_male_words)
expanded_target_sets.append(expanded_female_words)

target_sets_names = ['Expanded Male Terms', 'Expanded Female Terms']
attribute_sets = [arts, science]
attribute_sets_name = ['Arts','Science']
# create the query
query = Query(expanded_target_sets, attribute_sets, target_sets_names,
              attribute_sets_name)

WEAT().run_query(query, model1, calculate_p_value=True, p_value_iterations=5000)
# Out:
# {'query_name': 'Expanded Male Terms and Expanded Female Terms wrt Arts and Science',
#  'result': -0.6181904222272958,
#  'weat': -0.6181904222272958,
#  'effect_size': -1.2461499485226326,
#  'p_value': 0.9994001199760048}

# %% [markdown]
# #### Energy vs Science

# %%
energy = word_occuring_in_all_documents['Word'].to_list()
science = ['math', 'physics', 'chemistry', 'science', 'space', 'engineering']
expanded_male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
expanded_female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']

expanded_target_sets = []
expanded_target_sets.append(expanded_male_words)
expanded_target_sets.append(expanded_female_words)

target_sets_names = ['Expanded Male Terms', 'Expanded Female Terms']
attribute_sets = [energy, science]
attribute_sets_name = ['Energy','Science']
# create the query
query = Query(expanded_target_sets, attribute_sets, target_sets_names,
              attribute_sets_name)

WEAT().run_query(query, model1, calculate_p_value=True, p_value_iterations=5000)
# Out:
# {'query_name': 'Expanded Male Terms and Expanded Female Terms wrt Energy and Science',
#  'result': 0.1154445218160704,
#  'weat': 0.1154445218160704,
#  'effect_size': 0.48202549541226036,
#  'p_value': 0.1295740851829634}

# %% [markdown]
# #### Portugal vs Slovenia

# %%
os.chdir(output_data_location)
df_portugal = pd.read_csv('pt_final_necp_main_en_0.csv')
df_slovenia = pd.read_csv('si_final_necp_main_en_0.csv')

# %%
portugal_words = df_portugal['word'].to_list()
slovenia_words = df_slovenia['word'].to_list()
expanded_male_words = ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'father', 'uncle', 'grandfather']
expanded_female_words = ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter', 'mother', 'aunt', 'grandmother']

expanded_target_sets = []
expanded_target_sets.append(expanded_male_words)
expanded_target_sets.append(expanded_female_words)

target_sets_names = ['Expanded Male Terms', 'Expanded Female Terms']
attribute_sets = [portugal_words, slovenia_words]
attribute_sets_name = ['Portugal','Slovenia']
# create the query
query = Query(expanded_target_sets, attribute_sets, target_sets_names,
              attribute_sets_name)

WEAT().run_query(query, model1, calculate_p_value=True, p_value_iterations=5000)
# Out:
# {'query_name': 'Expanded Male Terms and Expanded Female Terms wrt Portugal and Slovenia',
#  'result': 0.06878002493780955,
#  'weat': 0.06878002493780955,
#  'effect_size': 0.8493012569540808,
#  'p_value': 0.023195360927814438}

# %% [markdown]
# #### Part 4: Reference

# %% [markdown]
# #### WEAT Test Sample Query

# %%
target_sets = [['she', 'woman', 'girl'], ['he', 'man', 'boy']]
target_sets_names = ['Female Terms', 'Male Terms']
attribute_sets = [['poetry','dance','literature'], ['math', 'physics', 'chemistry']]
attribute_sets_names = ['Arts', 'Science']
# create the query
query = Query(target_sets, attribute_sets, target_sets_names,
              attribute_sets_names)

# %%
WEAT().run_query(query, model1, calculate_p_value=True, p_value_iterations=5000)
# Out:
# {'query_name': 'Female Terms and Male Terms wrt Arts and Science',
#  'result': 0.2539585799289246,
#  'weat': 0.2539585799289246,
#  'effect_size': 1.852439227993748,
#  'p_value': 0.011095700416088766}

# %% [markdown]
# #### RND Test Sample Query

# %%
target_sets = [['she', 'woman', 'girl'], ['he', 'man', 'boy']]
target_sets_names = ['Female Terms', 'Male Terms']
attribute_sets = [['poetry','dance','literature']]
attribute_sets_names = ['Arts']
# create the query
query = Query(target_sets, attribute_sets, target_sets_names,
              attribute_sets_names)

# %%
RND().run_query(query, model1)
# Out:
# {'query_name': 'Female Terms and Male Terms wrt Arts',
#  'result': 0.004916667938232422,
#  'rnd': 0.004916667938232422,
#  'distances_by_word': {'dance': -0.045021057,
#   'literature': 0.020332098,
#   'poetry': 0.039438963}}
